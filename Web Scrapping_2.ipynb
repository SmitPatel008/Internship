# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\Admin\Desktop\chromedriver.exe")

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Analyst')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input")
location.send_keys('Bangalore')

# %%
Search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
Search.click()
time.sleep(3)

# %%
job_title=[]
job_location=[]
company_name=[]
experiance_required=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
experiance_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experiance_tags[0:10]:
    experiance=i.text
    experiance_required.append(experiance)

# %%
import pandas as pd
df=pd.DataFrame({'Title':job_title[0:10],'Location':job_location[0:10],'Company_name':company_name[0:10],'Experiance':experiance_required[0:10]})
df
# Out:
#                                Title  \
# 0                       Data Analyst
# 1                  Tech Data Analyst
# 2                       Data Analyst
# 3                       Data Analyst
# 4  Celonis & Salesforce Data Analyst
# 5  Celonis & Salesforce Data Analyst
# 6                       Data Analyst
# 7                       Data Analyst
# 8                       Data Analyst
# 9                       Data Analyst
#
#                                             Location  \
# 0                                Bangalore/Bengaluru
# 1  Hybrid - Bangalore/ Bengaluru, Karnataka, Gurg...
# 2                    Bangalore/ Bengaluru, Karnataka
# 3                                Bangalore/Bengaluru
# 4                       Bangalore/Bengaluru, Chennai
# 5                                Bangalore/Bengaluru
# 6                       Hybrid - Bangalore/Bengaluru
# 7          Hybrid - Bangalore/Bengaluru, Delhi / NCR
# 8          Hybrid - Bangalore/Bengaluru, Delhi / NCR
# ...

# %%
# Q2

driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input")
location.send_keys('Bangalore')

# %%
search1=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search1.click()

# %%
job_title1=[]
job_location1=[]
company_name1=[]

# %%
title1_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title1_tags[0:10]:
    title1=i.text
    job_title1.append(title1)
location1_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location1_tags[0:10]:
    location1=i.text
    job_location1.append(location1)
company1_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company1_tags[0:10]:
    company1=i.text
    company_name1.append(company1)

# %%
import pandas as pd
df2=pd.DataFrame({'Job Title':job_title1[0:10],'Location':job_location1[0:10],'Company_name':company_name1[0:10]})
df2
# Out:
#                                            Job Title  \
# 0  Permanent Opportunity - Data Scientist(Snaplog...
# 1                   Analystics & Modeling Specialist
# 2                    Machine Learning (AI) Architect
# 3                               Staff Data Scientist
# 4                                     Data Scientist
# 5                          Hiring For Data Scientist
# 6                                     Data Scientist
# 7            Director/Senior Director - Data Science
# 8              Manager/Senior Manager - Data Science
# 9                                     Data Scientist
#
#                                             Location  \
# 0  Hybrid - Bangalore/Bengaluru, Kolkata, Hyderab...
# 1  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...
# 2  Bangalore/Bengaluru, Kolkata, Mumbai, New Delh...
# 3                                Bangalore/Bengaluru
# 4                    Bangalore/ Bengaluru, Karnataka
# 5  Hybrid - Bangalore/ Bengaluru, Karnataka, Hyde...
# ...

# %%
# Q3
driver=webdriver.Chrome(r"chromedriver.exe")
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input ")
designation.send_keys('Data Scientist')

# %%
search12=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search12.click()

# %%
job_title2=[]
job_location2=[]
company_name2=[]
experiance_required2=[]

# %%
checkbox = driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[5]/div[2]/div[2]/label/p/span[1]")
checkbox.click()
time.sleep(3)

# %%
checkbox1 = driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[6]/div[2]/div[2]/label/p/span[1]")
checkbox1.click()
time.sleep(3)

# %%
title2_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title2_tags[0:10]:
    title2=i.text
    job_title2.append(title2)
location2_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location2_tags[0:10]:
    location2=i.text
    job_location2.append(location2)
company2_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company2_tags[0:10]:
    company2=i.text
    company_name2.append(company2)
experiance2_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experiance2_tags[0:10]:
    experiance2=i.text
    experiance_required2.append(experiance2)

# %%
import pandas as pd
df3=pd.DataFrame({'Title':job_title2[0:10],'Location':job_location2[0:10],'Company_name':company_name2[0:10],'Experiance':experiance_required2[0:10]})
df3
# Out:
#                     Title                                           Location  \
# 0   Junior Data Scientist  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# 1          Data Scientist              Gurgaon/Gurugram, Bangalore/Bengaluru
# 2          Data Scientist  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# 3   Python and ML Trainer  Hyderabad/Secunderabad, New Delhi, Pune, Gurga...
# 4          Data Scientist                                        Delhi / NCR
# 5                  Intern                                   Gurgaon/Gurugram
# 6  Lead Assistant Manager                                   Gurgaon/Gurugram
# 7          Data Scientist                                              Noida
# 8   Junior Data Scientist    Gurgaon/Gurugram, United States (USA), Bulgaria
# 9  MLOps - Data Scientist                                              Noida
#
#                       Company_name Experiance
# 0                         Analytos    0-2 Yrs
# ...

# %%
# Q4
driver=webdriver.Chrome(r"chromedriver.exe")
driver.get("https://www.flipkart.com/")

# %%
close=driver.find_element(By.XPATH,"/html/body/div[2]/div/div/button")
close.click()

# %%
Product4=driver.find_element(By.CLASS_NAME,"_3704LK")
Product4.send_keys('Sun Glasses')

# %%
search4=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search4.click()

# %%
Brand=[]
Product_Description=[]
Price=[]

# %%
start=0
end=4
for page in range(start,end):
    Brands=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in Brands:
        Brand.append(i.text)
    Description=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in Description:
        Product_Description.append(i.text)
    Prices=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in Prices:
        Price.append(i.text)
    Next=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]")
    Next.click() 
    time.sleep(5)

# %%
print(len(Brand),len(Product_Description),len(Price))
# Out:
# 160 156 160

# %%
import pandas as pd
df=pd.DataFrame({'Brand': Brand[0:100],'Product Description':Product_Description[0:100],'Price': Price[0:100]})
df
# Out:
#         Brand                                Product Description Price
# 0   ROYAL SON  UV Protection Rectangular, Retro Square Sungla...  ₹471
# 1   ROYAL SON              Polarized Rectangular Sunglasses (60)  ₹699
# 2        BKGE  Polarized, UV Protection Retro Square Sunglass...  ₹149
# 3    Fastrack   UV Protection Rectangular Sunglasses (Free Size)  ₹499
# 4   Elligator   UV Protection, Mirrored Wayfarer Sunglasses (54)  ₹109
# ..        ...                                                ...   ...
# 95     AISLIN             UV Protection Wayfarer Sunglasses (56)  ₹745
# 96  Elligator  UV Protection, Gradient Over-sized, Wayfarer S...  ₹149
# 97  Elligator        UV Protection Shield Sunglasses (Free Size)  ₹213
# 98     PIRASO             UV Protection Wayfarer Sunglasses (56)  ₹192
# 99      NuVew   UV Protection Rectangular Sunglasses (Free Size)  ₹403
#
# [100 rows x 3 columns]

# %%
# Q5
driver=webdriver.Chrome(r"chromedriver.exe")
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market")

# %%
Rating=[]
Review_summary=[]
Full_review=[]

# %%
start=0
end=12
for page in range(start,end):
    Ratings=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in Ratings:
        Rating.append(i.text)
    Review=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for i in Review:
        Review_summary.append(i.text)
    Fullreview=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for i in Fullreview:
        Full_review.append(i.text)
    Next=driver.find_element(By.XPATH,"/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[2]")
    Next.click() 
    time.sleep(3)

# %%
print(len(Rating),len(Review_summary),len(Full_review))
# Out:
# 120 120 120

# %%
import pandas as pd
df5=pd.DataFrame({'Rating': Rating[0:100],'Review summary':Review_summary[0:100],'Full_review': Full_review[0:100]})
df5
# Out:
#    Rating       Review summary  \
# 0       5       Simply awesome
# 1       5     Perfect product!
# 2       5  Best in the market!
# 3       4      Value-for-money
# 4       5   Highly recommended
# ..    ...                  ...
# 95      5     Perfect product!
# 96      5   Highly recommended
# 97      5   Highly recommended
# 98      4      Value-for-money
# 99      5     Perfect product!
#
#                                           Full_review
# 0   Really satisfied with the Product I received.....
# 1   Amazing phone with great cameras and better ba...
# 2   Great iPhone very snappy experience as apple k...
# 3   I'm Really happy with the product\nDelivery wa...
# 4   It's my first time to use iOS phone and I am l...
# ..                                                ...
# 95  Value for money❤️❤️\nIts awesome mobile phone ...
# 96  iphone 11 is a very good phone to buy only if ...
# 97  Amazing camera quality as expected, battery al...
# ...

# %%
# Q6
driver=webdriver.Chrome(r"chromedriver.exe")
driver.get("https://www.flipkart.com/")

# %%
close=driver.find_element(By.XPATH,"/html/body/div[2]/div/div/button")
close.click()

# %%
Product6=driver.find_element(By.CLASS_NAME,"_3704LK")
Product6.send_keys('Sneakers')

# %%
search6=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search6.click()

# %%
Brand6=[]
Product_Description6=[]
Price6=[]

# %%
start=0
end=3
for page in range(start,end):
    Brands6=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in Brands6:
        Brand6.append(i.text)
    Product_Descriptions6=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in Product_Descriptions6:
        Product_Description6.append(i.text)
    Prices6=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in Prices6:
        Price6.append(i.text)
    
    Next=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]")
    Next.click() 
    time.sleep(3)

# %%
print(len(Brand6),len(Product_Description6),len(Price6))

# %%
import pandas as pd
df6=pd.DataFrame({'Brand6': Brand6[0:100],'Product Description6':Product_Description6[0:100],'Price6': Price6[0:100]})
df6
# Out:
#                    Brand6                               Product Description6  \
# 0                   BIRDE      Combo Pack Of 2 Casual Shoes Sneakers For Men
# 1                RapidBox                                   Sneakers For Men
# 2                  Labbin                                   Sneakers For Men
# 3                    PUMA                              Buzz Sneakers For Men
# 4                    PUMA                         Hustle V2 Sneakers For Men
# ..                    ...                                                ...
# 95                   aadi                  RS-Z Reinvention Sneakers For Men
# 96               HOTSTYLE                          HRXLB-2C Sneakers For Men
# 97                   aadi  Original Luxury Branded Fashionable Men's Casu...
# 98                   PUMA                                   Sneakers For Men
# 99  HRX by Hrithik Roshan                         Hustle V2 Sneakers For Men
#
#     Price6
# 0     ₹499
# 1     ₹549
# ...

# %%
# Q7
driver=webdriver.Chrome(r"chromedriver.exe")
driver.get("https://www.amazon.in/")

# %%
Product7=driver.find_element(By.ID,"twotabsearchtextbox")
Product7.send_keys('Laptop')

# %%
search7=driver.find_element(By.ID,"nav-search-submit-button")
search7.click()
time.sleep(3)

# %%
i7=driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[6]/span[8]/li/span/a/div")
i7.click()

# %%
Title7=[]
Rating7=[]
Price7=[]

# %%
Titles7_tags=driver.find_elements(By.XPATH,'//span[@class="a-size-medium a-color-base a-text-normal"]')
for i in Titles7_tags[0:10]:
    Titles7=i.text
    Title7.append(Titles7)
Ratings7_tags=driver.find_elements(By.XPATH,'//i[@class="a-icon a-icon-star-small a-star-small-4 aok-align-bottom"]')
for i in Ratings7_tags[0:10]:
    Ratings7=i.text
    Rating7.append(Ratings7)
Prices7_tags=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
for i in Prices7_tags[0:10]:
    Prices7=i.text
    Price7.append(Prices7)

# %%
import pandas as pd
df7=pd.DataFrame({'Title': Title7[0:10],'Rating':Rating7[0:10],'Price': Price7[0:10]})
df7
# Out:
#                                                Title Rating   Price
# 0  Dell Vostro 3420 Laptop, Intel Core i5-1135G7,...         54,490
# 1  Lenovo IdeaPad Slim 3 Intel Core i5 12th Gen 1...         55,400
# 2  Dell Vostro 3510 Laptop, Intel Core i5-1135G7/...         52,490
# 3  (Renewed) DELL Latitude 5490 Core i5 7th Gen L...         79,490
# 4  HP Pavilion x360 13th Gen Intel Core i5-1335U ...         54,990
# 5  HP 15s, 12th Gen Intel Core i5 8GB RAM/512GB S...         49,490
# 6  Dell Vostro 3420 Laptop, Intel Core i5-1135G7,...         58,490
# 7  Dell Inspiron 3520 Laptop,12th Gen Intel Core ...         50,999
# 8  Xiaomi NotebookPro QHD+ IPS AntiGlare Display ...         66,800
# 9  HP Pavilion 14 12th Gen Intel Core i5 16GB RAM...         58,990

# %%
# Q8
driver=webdriver.Chrome(r"chromedriver.exe")
driver.get("https://www.azquotes.com/")
time.sleep(3)

# %%
topclick=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a")
topclick.click()
time.sleep(5)

# %%
Quote=[]
Author=[]
Type_of_Quotes=[]

# %%
start=0
end=20
for page in range(start,end):
    Quotes=driver.find_elements(By.XPATH,'//a[@class="title"]')
    for i in Quotes:
        Quote.append(i.text)
    Authors=driver.find_elements(By.XPATH,'//div[@class="author"]')
    for i in Authors:
        Author.append(i.text)
    Type_of_Quotes1=driver.find_elements(By.XPATH,'//div[@class="tags"]')
    for i in Type_of_Quotes1:
        Type_of_Quotes.append(i.text)
    
    Next=driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div/div/div/div[1]/div/div[3]/li[3]/a")
    Next.click() 
    time.sleep(1)

# %%
import pandas as pd
df8=pd.DataFrame({'Quote': Quote[0:1000],'Author':Author[0:1000],'Type of Quotes': Type_of_Quotes[0:1000]})
df8
# Out:
#                                                  Quote                 Author  \
# 0    The essence of strategy is choosing what not t...         Michael Porter
# 1    One cannot and must not try to erase the past ...             Golda Meir
# 2    Patriotism means to stand by the country. It d...     Theodore Roosevelt
# 3    Death is something inevitable. When a man has ...         Nelson Mandela
# 4    You have to love a nation that celebrates its ...           Erma Bombeck
# ..                                                 ...                    ...
# 995  When one door closes, another opens; but we of...  Alexander Graham Bell
# 996                   Don't find fault, find a remedy.             Henry Ford
# 997  I used to think the worst thing in life was to...         Robin Williams
# 998  Friends and good manners will carry you where ...        Margaret Walker
# 999  If you want to make a permanent change, stop f...           T. Harv Eker
#
# ...

# %%
# Q9
driver=webdriver.Chrome(r"chromedriver.exe")
driver.get("https://www.jagranjosh.com/")
time.sleep(3)

# %%
GK=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div/div[1]/div/div[5]/div/div[1]/header/div[3]/ul/li[3]/a")
GK.click()
time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7380\757175882.py in <module>
# ----> 1 GK=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div/div[1]/div/div[5]/div/div[1]/header/div[3]/ul/li[3]/a")
#       2 GK.click()
#       3 time.sleep(3)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     829             value = f'[name="{value}"]'
#     830
# --> 831         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     832
#     833     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     438         response = self.command_executor.execute(driver_command, params)
#     439         if response:
# ...

# %%
list1=driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a")
list1.click()
time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7380\1625928476.py in <module>
#       1 list1=driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a")
# ----> 2 list1.click()
#       3 time.sleep(3)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      92     def click(self) -> None:
#      93         """Clicks the element."""
# ---> 94         self._execute(Command.CLICK_ELEMENT)
#      95
#      96     def submit(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     401             params = {}
#     402         params["id"] = self._id
# --> 403         return self._parent.execute(command, params)
#     404
#     405     def find_element(self, by=By.ID, value=None) -> WebElement:
#
# ...

# %%
Name=[]
Born_Dead=[]
Term_of_Office=[]
Remarks=[]

# %%
names1_tags=driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[2]/div/div/div/div[4]/span/div[3]/table/tbody/tr[2]/td[2]/p/strong/a')
    names1=i.text
    Name.append(names1)
Borndead_tags=driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[2]/div/div/div/div[4]/span/div[2]/table/tbody/tr[2]/td[3]')
for i in Borndead_tags[0:100]:
    Borndead=i.text
    Born_Dead.append(Borndead)
Term_tags=driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[2]/div/div/div/div[4]/span/div[2]/table/tbody/tr[2]/td[4]')
for i in Term_tags[0:100]:
    Term=i.text
    Term_of_Office.append(Term)
Remarks1_tags=driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[2]/div/div/div/div[4]/span/div[2]/table/tbody/tr[2]/td[5]')
for i in Remarks1_tags[0:100]:
    Remarks1=i.text
    Remarks.append(Remarks1)

# %%
import pandas as pd
df9=pd.DataFrame({'Prime Ministers name': Name[0:100],'Born-Dead':Born_Dead[0:100],'Term of Office': Term_of_Office[0:100],'Remarks':Remarks[0:100]})
df9

# %%
# Q10
driver=webdriver.Chrome(r"chromedriver.exe")
driver.get("https://www.motor1.com/")

# %%
expcars=driver.find_element(By.ID,"search_input")
expcars.send_keys('50 most expensive cars')

# %%
search10=driver.find_element(By.XPATH,"/html/body/div[3]/div[2]/div/div/div[3]/div/div/div/form/button[1]")
search10.click()

# %%
search11=driver.find_element(By.XPATH,"/html/body/div[3]/div[9]/div/div[1]/div/div/div[2]/div/div[1]/h3/a")
search11.click()
time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7380\561511196.py in <module>
# ----> 1 search11=driver.find_element(By.XPATH,"/html/body/div[3]/div[9]/div/div[1]/div/div/div[2]/div/div[1]/h3/a")
#       2 search11.click()
#       3 time.sleep(10)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     829             value = f'[name="{value}"]'
#     830
# --> 831         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     832
#     833     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     438         response = self.command_executor.execute(driver_command, params)
#     439         if response:
# ...

# %%
Car_Name=[]
Price=[]

# %%
carname_tags=driver.find_elements(By.XPATH,'//h3[@class="subheader"]')
for i in carname_tags[0:50]:
    carname=i.text
    Car_Name.append(carname)
carprice_tags=driver.find_elements(By.XPATH,'//i[@class="a-icon a-icon-star-small a-star-small-4 aok-align-bottom"]')
for i in carprice_tags[0:50]:
    carprice=i.text
    Price.append(carprice)

# %%
print(len(Car_Name),len(Price))
# Out:
# 50 0

# %%
import pandas as pd
df10=pd.DataFrame({'Car Name': Car_Name[0:50]})
df10
# Out:
#                            Car Name
# 0                     De Tomaso P72
# 1                 Ferrari LaFerrari
# 2                     Pagani Huayra
# 3                      McLaren Elva
# 4                       Czinger 21C
# 5                     Ferrari Monza
# 6                Gordon Murray T.33
# 7                 Koenigsegg Gemera
# 8                       Zenvo TSR-S
# 9                Hennessey Venom F5
# 10                  Bentley Bacalar
# 11    Hispano Suiza Carmen Boulogne
# 12           Bentley Mulliner Batur
# 13                     Deus Vayanne
# 14                      SSC Tuatara
# 15                      Lotus Evija
# 16              Aston Martin Vulcan
# 17                       Delage D12
# 18                McLaren Speedtail
# 19                     Rimac Nevera
# 20                    Pagani Utopia
# 21             Pininfarina Battista
# 22                Ferrari FXX K Evo
# 23               Gordon Murray T.50
# 24             Lamborghini Countach
# ...
