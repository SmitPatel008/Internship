# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset3/main/weatherAUS.csv")

# %%
df
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1     2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2     2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3     2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4     2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# ...          ...      ...      ...      ...       ...          ...       ...
# 8420  2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 8421  2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 8422  2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 8423  2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
# 8424  2017-06-25    Uluru     14.9      NaN       0.0          NaN       NaN
#
# ...

# %% [markdown]
# here we have data of different location weather details like , temp, windspwwd, humidity, rain fall, Pressure, Cloud etc.

# %%
df.isnull().sum()
# Out:
# Date                0
# Location            0
# MinTemp            75
# MaxTemp            60
# Rainfall          240
# Evaporation      3512
# Sunshine         3994
# WindGustDir       991
# WindGustSpeed     991
# WindDir9am        829
# WindDir3pm        308
# WindSpeed9am       76
# WindSpeed3pm      107
# Humidity9am        59
# Humidity3pm       102
# Pressure9am      1309
# Pressure3pm      1312
# Cloud9am         2421
# Cloud3pm         2455
# Temp9am            56
# Temp3pm            96
# RainToday         240
# RainTomorrow      239
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   object
#  1   Location       8425 non-null   object
#  2   MinTemp        8350 non-null   float64
#  3   MaxTemp        8365 non-null   float64
#  4   Rainfall       8185 non-null   float64
#  5   Evaporation    4913 non-null   float64
#  6   Sunshine       4431 non-null   float64
#  7   WindGustDir    7434 non-null   object
#  8   WindGustSpeed  7434 non-null   float64
#  9   WindDir9am     7596 non-null   object
#  10  WindDir3pm     8117 non-null   object
#  11  WindSpeed9am   8349 non-null   float64
#  12  WindSpeed3pm   8318 non-null   float64
#  13  Humidity9am    8366 non-null   float64
#  14  Humidity3pm    8323 non-null   float64
#  15  Pressure9am    7116 non-null   float64
#  16  Pressure3pm    7113 non-null   float64
# ...

# %%
plt.figure(figsize=(15,8))
sns.lineplot(df['MinTemp'],df['MaxTemp'])
# Out:
# <AxesSubplot:xlabel='MinTemp', ylabel='MaxTemp'>

# %% [markdown]
# we can see temp data corerealtion of minimum and maximum.

# %%
sns.barplot(df['Rainfall'],df['Location'])
# Out:
# <AxesSubplot:xlabel='Rainfall', ylabel='Location'>

# %% [markdown]
# highest rainfall in Coffsharbour and lowest rainfall in Adelaide.

# %%
sns.barplot(df['MinTemp'],df['Location'])
# Out:
# <AxesSubplot:xlabel='MinTemp', ylabel='Location'>

# %%
sns.barplot(df['MaxTemp'],df['Location'])
# Out:
# <AxesSubplot:xlabel='MaxTemp', ylabel='Location'>

# %% [markdown]
# darwin city has reorded highest max temp which is more than 30 degrees celsius.

# %%
sns.barplot(df['WindGustSpeed'],df['Location'])
# Out:
# <AxesSubplot:xlabel='WindGustSpeed', ylabel='Location'>

# %% [markdown]
# wollongong has recorded highest wind speed and Brisbane has lowest wind speed recorded.

# %%
sns.violinplot(x='MinTemp',data=df)
# Out:
# <AxesSubplot:xlabel='MinTemp'>

# %% [markdown]
# most of time average min temperate is between 10 to 15 degrees celsius.

# %%
sns.violinplot(x='MaxTemp',data=df)
# Out:
# <AxesSubplot:xlabel='MaxTemp'>

# %% [markdown]
# most of time average max temperate is between 18 to 22 degrees celsius.

# %%
plt.figure(figsize=(15,10))
sns.countplot(df['Location'])
# Out:
# <AxesSubplot:xlabel='Location', ylabel='count'>

# %% [markdown]
# in our data highest no. data we have for Melbourne city and lowest data for Uluru.

# %%
plt.figure(figsize=(15,10))
sns.swarmplot(df['Location'],df['WindGustSpeed'])
# Out:
# <AxesSubplot:xlabel='Location', ylabel='WindGustSpeed'>

# %% [markdown]
# we can see the no of times windspeed recorded in all city, highest wind speed is recorded on Albury which is more tha 100km/h
# lowest recoreded in penrith,
# Brisbane has most of time wind speed is less than 40km/h ,
# wind speed is most of time between 40 to 60km/h for cities like albury and coffsharbour, wollongong, darwin.

# %%
plt.figure(figsize=(15,10))
sns.swarmplot(df['Location'],df['Sunshine'])
# Out:
# <AxesSubplot:xlabel='Location', ylabel='Sunshine'>

# %%
plt.figure(figsize=(18,10))
sns.catplot(x='WindGustDir',y='WindGustSpeed',kind='box',data=df,aspect=2)

# %% [markdown]
# average windspeed in every direction is 40km/h.
# highest difference is recorded on direction WNW which has 5 to 90 km/h.

# %%
plt.figure(figsize=(18,10))
sns.catplot(x='WindGustDir',y='Rainfall',kind='bar',data=df,aspect=2)

# %%
sns.lineplot(df['Pressure9am'],df['Humidity9am'])
# Out:
# <AxesSubplot:xlabel='Pressure9am', ylabel='Humidity9am'>

# %% [markdown]
# average humidty on 9am is between 60 to 80.

# %%
sns.lineplot(df['WindDir9am'],df['Humidity9am'])
# Out:
# <AxesSubplot:xlabel='WindDir9am', ylabel='Humidity9am'>

# %%
sns.lineplot(df['Pressure3pm'],df['Pressure9am'])
# Out:
# <AxesSubplot:xlabel='Pressure3pm', ylabel='Pressure9am'>

# %% [markdown]
# gradually line chart of pressure and 3 pm and 9 am, it is increasig gradully , it means there is no differnce in pressure at 9 am and 3 pm.

# %%
sns.lineplot(df['WindDir9am'],df['Pressure9am'])
# Out:
# <AxesSubplot:xlabel='WindDir9am', ylabel='Pressure9am'>

# %%
sns.lineplot(df['Temp9am'],df['Pressure9am'])
# Out:
# <AxesSubplot:xlabel='Temp9am', ylabel='Pressure9am'>

# %% [markdown]
# as temperature is incresing pressure is decreasing.

# %%
sns.lineplot(df['Temp9am'],df['Humidity9am'])
# Out:
# <AxesSubplot:xlabel='Temp9am', ylabel='Humidity9am'>

# %%
sns.lineplot(df['Temp9am'],df['Cloud9am'])
# Out:
# <AxesSubplot:xlabel='Temp9am', ylabel='Cloud9am'>

# %% [markdown]
# as temperature is incresing cloud is decreasing with variation.

# %%
sns.lineplot(df['Humidity9am'],df['Cloud9am'])
# Out:
# <AxesSubplot:xlabel='Humidity9am', ylabel='Cloud9am'>

# %% [markdown]
# as Humidity is incresing cloud is cloiud is also increasing , so we can say that cloud highly co relate with humidity.

# %%
sns.lineplot(df['Pressure9am'],df['Cloud9am'])
# Out:
# <AxesSubplot:xlabel='Pressure9am', ylabel='Cloud9am'>

# %% [markdown]
# we can see pressure range in our data which is between 990 to 1040 for all data.

# %%
sns.lineplot(df['Humidity9am'],df['Humidity3pm'])
# Out:
# <AxesSubplot:xlabel='Humidity9am', ylabel='Humidity3pm'>

# %% [markdown]
# here is corelation chart of humidity at 9 am and 3pm so we can see there is little bit change in both time zone.

# %%
sns.barplot(df['RainToday'],df['Temp9am'])
# Out:
# <AxesSubplot:xlabel='RainToday', ylabel='Temp9am'>

# %% [markdown]
# when there is rain fall avg temperature of that day at 9 am is less than 17.5 degrees celsius.and day when not rain fall avg temprate is more than 17.5 degrees celsius.

# %%
sns.barplot(df['RainToday'],df['Temp3pm'])
# Out:
# <AxesSubplot:xlabel='RainToday', ylabel='Temp3pm'>

# %% [markdown]
# rainy day avg temperature at 3 pm is 20 degrees celsius.

# %%
sns.barplot(df['RainToday'],df['Cloud9am'])
# Out:
# <AxesSubplot:xlabel='RainToday', ylabel='Cloud9am'>

# %% [markdown]
# on rainy day avg Fraction of sky obscured by cloud at 9 am is 6.

# %%
sns.barplot(df['RainToday'],df['Cloud3pm'])
# Out:
# <AxesSubplot:xlabel='RainToday', ylabel='Cloud3pm'>

# %%
sns.barplot(df['RainToday'],df['Sunshine'])
# Out:
# <AxesSubplot:xlabel='RainToday', ylabel='Sunshine'>

# %% [markdown]
# on rainy day avg sunshine hours is 5.5 hours , and on other days avg sunshine hours is 8 hours.

# %%
sns.barplot(df['RainToday'],df['Pressure9am'])
# Out:
# <AxesSubplot:xlabel='RainToday', ylabel='Pressure9am'>

# %%
sns.barplot(df['RainToday'],df['Humidity9am'])
# Out:
# <AxesSubplot:xlabel='RainToday', ylabel='Humidity9am'>

# %% [markdown]
# On rainy day average humidity at 9 am is 80%.

# %%
sns.lineplot(df['Rainfall'],df['Evaporation'])
# Out:
# <AxesSubplot:xlabel='Rainfall', ylabel='Evaporation'>

# %%
sns.barplot(df['RainToday'],df['MaxTemp'])
# Out:
# <AxesSubplot:xlabel='RainToday', ylabel='MaxTemp'>

# %% [markdown]
# On Rainy avg max temperatue is 22 degrees celsius , while in other days it is 25 degrees celsius.

# %%
plt.scatter(df['Pressure9am'],df['Humidity9am'])

# %% [markdown]
# Most of pressure at 9 amd is between 1000 to 1030 (hpa).

# %%
mean_temp = df['MinTemp'].mean()
df['MinTemp'].fillna(mean_temp, inplace=True)
mean_tempmax = df['MaxTemp'].mean()
df['MaxTemp'].fillna(mean_tempmax, inplace=True)
mean_rainfall = df['Rainfall'].mean()
df['Rainfall'].fillna(mean_rainfall, inplace=True)
mean_Evaporation = df['Evaporation'].mean()
df['Evaporation'].fillna(mean_Evaporation, inplace=True)
mean_Sunshine = df['Sunshine'].mean()
df['Sunshine'].fillna(mean_Sunshine, inplace=True)
mean_WindGustSpeed = df['WindGustSpeed'].mean()
df['WindGustSpeed'].fillna(mean_WindGustSpeed, inplace=True)
mean_WindSpeed9am = df['WindSpeed9am'].mean()
df['WindSpeed9am'].fillna(mean_WindSpeed9am, inplace=True)
mean_WindSpeed3pm = df['WindSpeed3pm'].mean()
df['WindSpeed3pm'].fillna(mean_WindSpeed3pm, inplace=True)
mean_Humidity9am = df['Humidity9am'].mean()
df['Humidity9am'].fillna(mean_Humidity9am, inplace=True)
mean_Humidity3pm = df['Humidity3pm'].mean()
df['Humidity3pm'].fillna(mean_Humidity3pm, inplace=True)
mean_Pressure9am = df['Pressure9am'].mean()
df['Pressure9am'].fillna(mean_Pressure9am, inplace=True)
mean_Pressure3pm = df['Pressure3pm'].mean()
df['Pressure3pm'].fillna(mean_Pressure3pm, inplace=True)
mean_Cloud9am = df['Cloud9am'].mean()
df['Cloud9am'].fillna(mean_Cloud9am, inplace=True)
mean_Cloud3pm = df['Cloud3pm'].mean()
df['Cloud3pm'].fillna(mean_Cloud3pm, inplace=True)
mean_Temp9am = df['Temp9am'].mean()
df['Temp9am'].fillna(mean_Temp9am, inplace=True)
mean_Temp3pm = df['Temp3pm'].mean()
df['Temp3pm'].fillna(mean_Temp3pm, inplace=True)

# %% [markdown]
# we many rows with nan values so not droing that row we fill nan values with its means value of each column.

# %%
df.isnull().sum()
# Out:
# Date               0
# Location           0
# MinTemp            0
# MaxTemp            0
# Rainfall           0
# Evaporation        0
# Sunshine           0
# WindGustDir      991
# WindGustSpeed      0
# WindDir9am       829
# WindDir3pm       308
# WindSpeed9am       0
# WindSpeed3pm       0
# Humidity9am        0
# Humidity3pm        0
# Pressure9am        0
# Pressure3pm        0
# Cloud9am           0
# Cloud3pm           0
# Temp9am            0
# Temp3pm            0
# RainToday        240
# RainTomorrow     239
# dtype: int64

# %%
mode_WindGustDir = df['WindGustDir'].mode()[0]
df['WindGustDir'].fillna(mode_WindGustDir, inplace=True)
mode_WindDir9am = df['WindDir9am'].mode()[0]
df['WindDir9am'].fillna(mode_WindDir9am, inplace=True)
mode_WindDir3pm = df['WindDir3pm'].mode()[0]
df['WindDir3pm'].fillna(mode_WindDir3pm, inplace=True)
mode_RainToday = df['RainToday'].mode()[0]
df['RainToday'].fillna(mode_RainToday, inplace=True)
mode_RainTomorrow = df['RainTomorrow'].mode()[0]
df['RainTomorrow'].fillna(mode_RainTomorrow, inplace=True)

# %% [markdown]
# we fill nan values with model for object data type columns.

# %%
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %%
df.skew()
# Out:
# MinTemp          -0.089989
# MaxTemp           0.380654
# Rainfall         13.218403
# Evaporation      14.023948
# Sunshine         -0.716525
# WindGustSpeed     0.757000
# WindSpeed9am      0.960591
# WindSpeed3pm      0.494217
# Humidity9am      -0.256743
# Humidity3pm       0.118281
# Pressure9am      -0.024082
# Pressure3pm      -0.010214
# Cloud9am         -0.366503
# Cloud3pm         -0.276294
# Temp9am          -0.014748
# Temp3pm           0.397331
# dtype: float64

# %% [markdown]
# we have skewnees is column rainfall and evaporation so we adjust it.

# %%
df['Rainfall']=np.cbrt(df['Rainfall'])
df['Evaporation']=np.cbrt(df['Evaporation'])

# %%
df.skew()
# Out:
# MinTemp         -0.089989
# MaxTemp          0.380654
# Rainfall         1.622698
# Evaporation      0.176211
# Sunshine        -0.716525
# WindGustSpeed    0.757000
# WindSpeed9am     0.960591
# WindSpeed3pm     0.494217
# Humidity9am     -0.256743
# Humidity3pm      0.118281
# Pressure9am     -0.024082
# Pressure3pm     -0.010214
# Cloud9am        -0.366503
# Cloud3pm        -0.276294
# Temp9am         -0.014748
# Temp3pm          0.397331
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   object
#  1   Location       8425 non-null   object
#  2   MinTemp        8425 non-null   float64
#  3   MaxTemp        8425 non-null   float64
#  4   Rainfall       8425 non-null   float64
#  5   Evaporation    8425 non-null   float64
#  6   Sunshine       8425 non-null   float64
#  7   WindGustDir    8425 non-null   object
#  8   WindGustSpeed  8425 non-null   float64
#  9   WindDir9am     8425 non-null   object
#  10  WindDir3pm     8425 non-null   object
#  11  WindSpeed9am   8425 non-null   float64
#  12  WindSpeed3pm   8425 non-null   float64
#  13  Humidity9am    8425 non-null   float64
#  14  Humidity3pm    8425 non-null   float64
#  15  Pressure9am    8425 non-null   float64
#  16  Pressure3pm    8425 non-null   float64
# ...

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

le = LabelEncoder()
df['WindGustDir'] = le.fit_transform(df['WindGustDir'])
df['WindDir9am'] = le.fit_transform(df['WindDir9am'])
df['WindDir3pm'] = le.fit_transform(df['WindDir3pm'])

# %%
df['RainToday'] = le.fit_transform(df['RainToday'])
df['RainTomorrow'] = le.fit_transform(df['RainTomorrow'])

# %% [markdown]
# Here we convert object data type column into numeric format for model prediction.

# %%
df.corr()
# Out:
#                 MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp        1.000000  0.717522  0.095545     0.346449  0.056184
# MaxTemp        0.717522  1.000000 -0.217687     0.441630  0.378403
# Rainfall       0.095545 -0.217687  1.000000    -0.131190 -0.272221
# Evaporation    0.346449  0.441630 -0.131190     1.000000  0.344597
# Sunshine       0.056184  0.378403 -0.272221     0.344597  1.000000
# WindGustDir   -0.145316 -0.224670  0.125775    -0.106130 -0.105918
# WindGustSpeed  0.230058  0.139998  0.102623     0.160565 -0.013778
# WindDir9am    -0.041650 -0.214119  0.163901    -0.076953 -0.076560
# WindDir3pm    -0.147166 -0.180622  0.104215    -0.047217 -0.068553
# WindSpeed9am   0.136872  0.013314  0.045355     0.097751 -0.018069
# WindSpeed3pm   0.178349  0.088172  0.035251     0.094527  0.030145
# Humidity9am   -0.130731 -0.390976  0.411744    -0.281646 -0.360831
# Humidity3pm    0.079048 -0.421879  0.392776    -0.213591 -0.440268
# ...

# %% [markdown]
# # Predicting whether or not it will rain tomorrow.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
x = df.iloc[:,2:22]

# %%
y=df.iloc[:,-1]

# %%
x.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0     13.4     22.9  0.843433     1.753261  7.632205           13
# 1      7.4     25.1  0.000000     1.753261  7.632205           14
# 2     12.9     25.7  0.000000     1.753261  7.632205           15
# 3      9.2     28.0  0.000000     1.753261  7.632205            4
# 4     17.5     32.3  1.000000     1.753261  7.632205           13
#
#    WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# 0           44.0          13          14          20.0          24.0
# 1           44.0           6          15           4.0          22.0
# 2           46.0          13          15          19.0          26.0
# 3           24.0           9           0          11.0           9.0
# 4           41.0           1           7           7.0          20.0
#
#    Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# 0         71.0         22.0       1007.7       1007.1  8.000000  4.503183
# ...

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: RainTomorrow, dtype: int32

# %%
from sklearn.preprocessing import StandardScaler

# %%
st=StandardScaler()
x=st.fit_transform(x)
x
# Out:
# array([[ 3.84250100e-02, -1.57008852e-01,  2.92627140e-01, ...,
#         -1.53712470e-01, -1.08138052e-01, -5.56099190e-01],
#        [-1.07698898e+00,  2.02812062e-01, -6.41375723e-01, ...,
#         -1.00217155e-01,  3.12348332e-01, -5.56099190e-01],
#        [-5.45261556e-02,  3.00945038e-01, -6.41375723e-01, ...,
#          5.77390162e-01,  1.27334323e-01, -5.56099190e-01],
#        ...,
#        [-1.44879364e+00,  4.97210991e-01, -6.41375723e-01, ...,
#         -9.38310416e-01,  6.15098528e-01, -5.56099190e-01],
#        [-1.00262804e+00,  5.13566487e-01, -6.41375723e-01, ...,
#         -4.74684357e-01,  5.98279073e-01, -5.56099190e-01],
#        [ 3.17278507e-01, -2.90531973e-15, -6.41375723e-01, ...,
#         -4.92516128e-01, -2.59513150e-01, -5.56099190e-01]])

# %% [markdown]
# applying scaller to data for better performance of our model.

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)

# %%
lg = LogisticRegression()
lg.fit(x_train, y_train)
predlg=lg.predict(x_test)
print(accuracy_score(y_test,predlg))
print(confusion_matrix(y_test,predlg))
print(classification_report(y_test,predlg))
# Out:
# 0.8528189910979228
# [[1243   71]
#  [ 177  194]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91      1314
#            1       0.73      0.52      0.61       371
#
#     accuracy                           0.85      1685
#    macro avg       0.80      0.73      0.76      1685
# weighted avg       0.84      0.85      0.84      1685

# %% [markdown]
# LogisticRegression model accuracy is 85%.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier,AdaBoostClassifier, GradientBoostingClassifier, BaggingClassifier
from sklearn.naive_bayes import GaussianNB

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc=dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 0.857566765578635
# [[1180  134]
#  [ 106  265]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91      1314
#            1       0.66      0.71      0.69       371
#
#     accuracy                           0.86      1685
#    macro avg       0.79      0.81      0.80      1685
# weighted avg       0.86      0.86      0.86      1685

# %% [markdown]
# DecisionTreeClassifier model accuracy is 85%.

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
predknn=knn.predict(x_test)
print(accuracy_score(y_test,predknn))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 0.8456973293768546
# [[1180  134]
#  [ 106  265]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91      1314
#            1       0.66      0.71      0.69       371
#
#     accuracy                           0.86      1685
#    macro avg       0.79      0.81      0.80      1685
# weighted avg       0.86      0.86      0.86      1685

# %% [markdown]
# KNeighborsClassifier model accuracy is 84.5%.

# %%
RFC = RandomForestClassifier()
RFC.fit(x_train, y_train)
predRFC = RFC.predict(x_test)
print(accuracy_score(y_test, predRFC))
print(confusion_matrix(y_test,predRFC))
print(classification_report(y_test,predRFC))
# Out:
# 0.914540059347181
# [[1277   37]
#  [ 107  264]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95      1314
#            1       0.88      0.71      0.79       371
#
#     accuracy                           0.91      1685
#    macro avg       0.90      0.84      0.87      1685
# weighted avg       0.91      0.91      0.91      1685

# %% [markdown]
# RandomForestClassifier model accuracy is 91%.

# %%
ad=AdaBoostClassifier()
ad.fit(x_train,y_train)
ad_pred=ad.predict(x_test)
print(accuracy_score(y_test,ad_pred))
print(confusion_matrix(y_test,ad_pred))
print(classification_report(y_test,ad_pred))
# Out:
# 0.8545994065281899
# [[1239   75]
#  [ 170  201]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      1314
#            1       0.73      0.54      0.62       371
#
#     accuracy                           0.85      1685
#    macro avg       0.80      0.74      0.77      1685
# weighted avg       0.85      0.85      0.85      1685

# %% [markdown]
# AdaBoostClassifier model accuracy is 85%.

# %%
GB = GradientBoostingClassifier()
GB.fit(x_train, y_train)
predGB = GB.predict(x_test)
print(accuracy_score(y_test, predGB))
print(confusion_matrix(y_test,predGB))
print(classification_report(y_test,predGB))
# Out:
# 0.8611275964391691
# [[1251   63]
#  [ 171  200]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91      1314
#            1       0.76      0.54      0.63       371
#
#     accuracy                           0.86      1685
#    macro avg       0.82      0.75      0.77      1685
# weighted avg       0.85      0.86      0.85      1685

# %% [markdown]
# GradientBoostingClassifier model accuracy is 86%.

# %%
BC = BaggingClassifier()
BC.fit(x_train, y_train)
predBC = BC.predict(x_test)
print(accuracy_score(y_test, predBC))
print(confusion_matrix(y_test,predBC))
print(classification_report(y_test,predBC))
# Out:
# 0.9020771513353115
# [[1268   46]
#  [ 119  252]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94      1314
#            1       0.85      0.68      0.75       371
#
#     accuracy                           0.90      1685
#    macro avg       0.88      0.82      0.85      1685
# weighted avg       0.90      0.90      0.90      1685

# %% [markdown]
# BaggingClassifier model accuracy is 90%.

# %%
ETC = ExtraTreesClassifier()
ETC.fit(x_train, y_train)
predETC = ETC.predict(x_test)
print(accuracy_score(y_test, predETC))
print(confusion_matrix(y_test,predETC))
print(classification_report(y_test,predETC))
# Out:
# 0.9181008902077151
# [[1285   29]
#  [ 109  262]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      1314
#            1       0.90      0.71      0.79       371
#
#     accuracy                           0.92      1685
#    macro avg       0.91      0.84      0.87      1685
# weighted avg       0.92      0.92      0.91      1685

# %% [markdown]
# ExtraTreesClassifier model accuracy is 91%.

# %%
gnb = GaussianNB()
gnb.fit(x_train, y_train)
predgnb = gnb.predict(x_test)
print(accuracy_score(y_test, predgnb))
print(confusion_matrix(y_test,predgnb))
print(classification_report(y_test,predgnb))
# Out:
# 0.7946587537091988
# [[1095  219]
#  [ 127  244]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.83      0.86      1314
#            1       0.53      0.66      0.59       371
#
#     accuracy                           0.79      1685
#    macro avg       0.71      0.75      0.72      1685
# weighted avg       0.81      0.79      0.80      1685

# %% [markdown]
# GaussianNB model accuracy is 78%.

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
param_grid = param_grid = { 'n_estimators': [100, 200, 300], 'max_depth': [None, 10, 20, 30],'min_samples_split': [2, 5, 10],'min_samples_leaf': [1, 2, 4],'max_features': ['auto', 'sqrt', 'log2']}
model=RandomForestClassifier()
rsearch=RandomizedSearchCV(estimator=model, param_distributions=param_grid, n_iter=10,cv=3)
rsearch.fit(x,y)
print(rsearch)
print(rsearch.best_score_)
print(rsearch.best_estimator_)
# Out:
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(),
#                    param_distributions={'max_depth': [None, 10, 20, 30],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [100, 200, 300]})
# 0.8316937705658484
# RandomForestClassifier(max_depth=10, min_samples_split=5, n_estimators=200)

# %% [markdown]
# we applying hyper tuning method RandomizedSearchCV for model RandomForestClassifier. as we have highest accuracy in that which is 91%.

# %%
RFC = RandomForestClassifier(max_depth=20, min_samples_leaf=2)
RFC.fit(x_train, y_train)
predRFC = RFC.predict(x_test)
print(accuracy_score(y_test, predRFC))
print(confusion_matrix(y_test,predRFC))
print(classification_report(y_test,predRFC))
# Out:
# 0.9091988130563798
# [[1280   34]
#  [ 119  252]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94      1314
#            1       0.88      0.68      0.77       371
#
#     accuracy                           0.91      1685
#    macro avg       0.90      0.83      0.86      1685
# weighted avg       0.91      0.91      0.90      1685

# %% [markdown]
# after applying hyper tuning our final accuracy for model RandomForestClassifier 90%.

# %%
import joblib 

joblib.dump(predRFC, 'tomorrow_rainfallyes_or_not.pkl')
# Out:
# ['tomorrow_rainfallyes_or_not.pkl']

# %% [markdown]
# # Predicting Rainfall.

# %%
df
# Out:
#             Date Location  MinTemp    MaxTemp  Rainfall  Evaporation  \
# 0     2008-12-01   Albury     13.4  22.900000  0.843433     1.753261
# 1     2008-12-02   Albury      7.4  25.100000  0.000000     1.753261
# 2     2008-12-03   Albury     12.9  25.700000  0.000000     1.753261
# 3     2008-12-04   Albury      9.2  28.000000  0.000000     1.753261
# 4     2008-12-05   Albury     17.5  32.300000  1.000000     1.753261
# ...          ...      ...      ...        ...       ...          ...
# 8420  2017-06-21    Uluru      2.8  23.400000  0.000000     1.753261
# 8421  2017-06-22    Uluru      3.6  25.300000  0.000000     1.753261
# 8422  2017-06-23    Uluru      5.4  26.900000  0.000000     1.753261
# 8423  2017-06-24    Uluru      7.8  27.000000  0.000000     1.753261
# 8424  2017-06-25    Uluru     14.9  23.859976  0.000000     1.753261
#
#       Sunshine  WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  \
# ...

# %%
df
# Out:
#             Date Location  MinTemp    MaxTemp  Rainfall  Evaporation  \
# 0     2008-12-01   Albury     13.4  22.900000  0.843433     1.753261
# 1     2008-12-02   Albury      7.4  25.100000  0.000000     1.753261
# 2     2008-12-03   Albury     12.9  25.700000  0.000000     1.753261
# 3     2008-12-04   Albury      9.2  28.000000  0.000000     1.753261
# 4     2008-12-05   Albury     17.5  32.300000  1.000000     1.753261
# ...          ...      ...      ...        ...       ...          ...
# 8420  2017-06-21    Uluru      2.8  23.400000  0.000000     1.753261
# 8421  2017-06-22    Uluru      3.6  25.300000  0.000000     1.753261
# 8422  2017-06-23    Uluru      5.4  26.900000  0.000000     1.753261
# 8423  2017-06-24    Uluru      7.8  27.000000  0.000000     1.753261
# 8424  2017-06-25    Uluru     14.9  23.859976  0.000000     1.753261
#
#       Sunshine  WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   object
#  1   Location       8425 non-null   object
#  2   MinTemp        8425 non-null   float64
#  3   MaxTemp        8425 non-null   float64
#  4   Rainfall       8425 non-null   float64
#  5   Evaporation    8425 non-null   float64
#  6   Sunshine       8425 non-null   float64
#  7   WindGustDir    8425 non-null   int32
#  8   WindGustSpeed  8425 non-null   float64
#  9   WindDir9am     8425 non-null   int32
#  10  WindDir3pm     8425 non-null   int32
#  11  WindSpeed9am   8425 non-null   float64
#  12  WindSpeed3pm   8425 non-null   float64
#  13  Humidity9am    8425 non-null   float64
#  14  Humidity3pm    8425 non-null   float64
#  15  Pressure9am    8425 non-null   float64
#  16  Pressure3pm    8425 non-null   float64
# ...

# %%
x = df.iloc[:,2:4].join(df.iloc[:, 5:])

# %%
y = df.iloc[:,4:5]

# %%
x.head()
# Out:
#    MinTemp  MaxTemp  Evaporation  Sunshine  WindGustDir  WindGustSpeed  \
# 0     13.4     22.9     1.753261  7.632205           13           44.0
# 1      7.4     25.1     1.753261  7.632205           14           44.0
# 2     12.9     25.7     1.753261  7.632205           15           46.0
# 3      9.2     28.0     1.753261  7.632205            4           24.0
# 4     17.5     32.3     1.753261  7.632205           13           41.0
#
#    WindDir9am  WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# 0          13          14          20.0          24.0         71.0
# 1           6          15           4.0          22.0         44.0
# 2          13          15          19.0          26.0         38.0
# 3           9           0          11.0           9.0         45.0
# 4           1           7           7.0          20.0         82.0
#
#    Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# ...

# %%
y.head()
# Out:
#    Rainfall
# 0  0.843433
# 1  0.000000
# 2  0.000000
# 3  0.000000
# 4  1.000000

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=50)

# %%
lm = LinearRegression()
lm.fit(x_train, y_train)
lm.score(x_train,y_train)
# Out:
# 0.7421244211071352

# %% [markdown]
# LinearRegression score is 74%.

# %%
from sklearn.linear_model import Lasso,Ridge

# %%
ls=Lasso(alpha=0.001)
ls.fit(x_train,y_train)
print(ls.score(x_train,y_train))
# Out:
# 0.7420841766558874

# %% [markdown]
# lasso score is 74%.

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)


preddtr=dtr.predict(x_test)
print('DTR score :',dtr.score(x_train,y_train))
print('DTR r2_score:',r2_score(y_test,preddtr))
# Out:
# DTR score : 0.9992003689222152
# DTR r2_score: 0.7109197320567726

# %% [markdown]
# DecisionTreeRegressor score is 99%.

# %%
svr=SVR ()
svr.fit(x_train,y_train)
print(svr.score(x_train,y_train))
pred_y=svr.predict(x_test)
pred_y
print('Mean Squared error :',np.sqrt(mean_squared_error(y_test,pred_y)))

svr=SVR (kernel='poly')
svr.fit(x_train,y_train)
print(svr.score(x_train,y_train))
pred_y=svr.predict(x_test)
pred_y
print('Mean Squared error :',np.sqrt(mean_squared_error(y_test,pred_y)))

svr=SVR (kernel='rbf')
svr.fit(x_train,y_train)
print(svr.score(x_train,y_train))
pred_y=svr.predict(x_test)
pred_y
print('Mean Squared error :',np.sqrt(mean_squared_error(y_test,pred_y)))
# Out:
# 0.050439604040777075
# Mean Squared error : 0.8683581255416274
# 0.11627382979626899
# Mean Squared error : 0.8380823452508912
# 0.050439604040777075
# Mean Squared error : 0.8683581255416274

# %%
knr=KNeighborsRegressor()
knr.fit(x_train,y_train)
print('knr score',knr.score(x_train,y_train))


mse = mean_squared_error(y_test, preddtr)
r2 = r2_score(y_test, preddtr)
print("r2 Score:", r2)
# Out:
# knr score 0.5743873404840008
# r2 Score: 0.7109197320567726

# %% [markdown]
# KNeighborsRegressor score is 57%.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
rf=RandomForestRegressor(n_estimators=100,random_state=42)
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print('Rf score :',rf.score(x_train,y_train))
print('rf r2_score:',r2_score(y_test,predrf))
# Out:
# Rf score : 0.9735586770540902
# rf r2_score: 0.8376669857617609

# %% [markdown]
# RandomForestRegressor score is 97%.

# %%
ada=AdaBoostRegressor(n_estimators=100,random_state=42)
ada.fit(x_train,y_train)
predada=ada.predict(x_test)
print('Ada score :',ada.score(x_train,y_train))
print('Ada r2_score:',r2_score(y_test,predada))
# Out:
# Ada score : 0.6955301220123955
# Ada r2_score: 0.6934913736906423

# %% [markdown]
# AdaBoostRegressor score is 69%.

# %%
Gbr=GradientBoostingRegressor()
Gbr.fit(x_train,y_train)
predGbr=Gbr.predict(x_test)
print('Gbr score :',Gbr.score(x_train,y_train))
print('Gbr r2_score:',r2_score(y_test,predGbr))
# Out:
# Gbr score : 0.8131911753058343
# Gbr r2_score: 0.7842070535786291

# %% [markdown]
# GradientBoostingRegressor score is 81%

# %%
import joblib 

joblib.dump(preddtr, 'raingfall.pkl')
# Out:
# ['raingfall.pkl']
