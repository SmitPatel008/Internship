# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
file = r'C:\Users\Admin\Downloads\Country-Code.xlsx'
df1 = pd.read_excel(file)

# %%
url = "https://raw.githubusercontent.com/dsrscientist/dataset4/main/zomato.csv"
df2 = pd.read_csv(url, encoding='ISO-8859-1')

# %% [markdown]
# Here we two datasets

# %%
df=pd.merge (df1,df2)

# %% [markdown]
# We merge data set in one

# %%
df
# Out:
#       Country Code        Country  Restaurant ID  \
# 0                1          India        3400025
# 1                1          India        3400341
# 2                1          India        3400005
# 3                1          India        3400021
# 4                1          India        3400017
# ...            ...            ...            ...
# 9546           216  United States       17697389
# 9547           216  United States       17697424
# 9548           216  United States       17697332
# 9549           216  United States       17694056
# 9550           216  United States       17559793
#
#                                Restaurant Name            City  \
# 0                                   Jahanpanah            Agra
# 1                          Rangrezz Restaurant            Agra
# 2                      Time2Eat - Mama Chicken            Agra
# 3        Chokho Jeeman Marwari Jain Bhojanalya            Agra
# ...

# %% [markdown]
# we have data for all restraunt data like its address , location, price, cuisine etc data we have in this data set

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country Code          9551 non-null   int64
#  1   Country               9551 non-null   object
#  2   Restaurant ID         9551 non-null   int64
#  3   Restaurant Name       9551 non-null   object
#  4   City                  9551 non-null   object
#  5   Address               9551 non-null   object
#  6   Locality              9551 non-null   object
#  7   Locality Verbose      9551 non-null   object
#  8   Longitude             9551 non-null   float64
#  9   Latitude              9551 non-null   float64
#  10  Cuisines              9542 non-null   object
#  11  Average Cost for two  9551 non-null   int64
#  12  Currency              9551 non-null   object
#  13  Has Table booking     9551 non-null   object
#  14  Has Online delivery   9551 non-null   object
# ...

# %%
plt.figure(figsize=(15, 6))
sns.countplot(df['Country'])
plt.xticks(rotation=50)
plt.show()

# %% [markdown]
# We can see most of restraunts are in India which is more than 8000, and on second highest is united stated restraunts which very less two compare to india restraunt no.

# %%
sns.countplot(df['Has Table booking'])
# Out:
# <AxesSubplot:xlabel='Has Table booking', ylabel='count'>

# %% [markdown]
# we can only 1000+ restraunts has table booking.

# %%
sns.countplot(df['Has Online delivery'])
# Out:
# <AxesSubplot:xlabel='Has Online delivery', ylabel='count'>

# %% [markdown]
# we can see almost 2500 restraunts has online delivery, other 7000+ restraunt has no online delivery.

# %%
sns.countplot(df['Is delivering now'])
# Out:
# <AxesSubplot:xlabel='Is delivering now', ylabel='count'>

# %% [markdown]
# from this chart we can see most of restraunt not delivering now.

# %%
sns.countplot(df['Price range'])
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='count'>

# %% [markdown]
# highest no. of restraunt has price range of 1 and then gradually decresing no of restraunt count if incresing price range.

# %%
plt.figure(figsize=(15, 6))
sns.countplot(df['Aggregate rating'])
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='count'>

# %% [markdown]
# most rating given is 3.1 and 3.2 to restraunt.

# %%
sns.countplot(df['Rating text'])
# Out:
# <AxesSubplot:xlabel='Rating text', ylabel='count'>

# %% [markdown]
# More than 3500+ restraunt has rating of average , and 2000+ restraunt has good rating , 1000 restraunt has very good rating and almost 250 restraunt has excellent rating

# %%
plt.figure(figsize=(15, 6))
sns.barplot(df['Rating text'],df['Price range'])
# Out:
# <AxesSubplot:xlabel='Rating text', ylabel='Price range'>

# %%
sns.barplot(df['Has Table booking'],df['Price range'])
# Out:
# <AxesSubplot:xlabel='Has Table booking', ylabel='Price range'>

# %%
sns.barplot(df['Rating text'],df['Votes'])
# Out:
# <AxesSubplot:xlabel='Rating text', ylabel='Votes'>

# %%
df.isnull().sum()
# Out:
# Country Code            0
# Country                 0
# Restaurant ID           0
# Restaurant Name         0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country Code          9551 non-null   int64
#  1   Country               9551 non-null   object
#  2   Restaurant ID         9551 non-null   int64
#  3   Restaurant Name       9551 non-null   object
#  4   City                  9551 non-null   object
#  5   Address               9551 non-null   object
#  6   Locality              9551 non-null   object
#  7   Locality Verbose      9551 non-null   object
#  8   Longitude             9551 non-null   float64
#  9   Latitude              9551 non-null   float64
#  10  Cuisines              9542 non-null   object
#  11  Average Cost for two  9551 non-null   int64
#  12  Currency              9551 non-null   object
#  13  Has Table booking     9551 non-null   object
#  14  Has Online delivery   9551 non-null   object
# ...

# %%
df[['Average Cost for two','Currency']]
# Out:
#       Average Cost for two            Currency
# 0                      850  Indian Rupees(Rs.)
# 1                      700  Indian Rupees(Rs.)
# 2                      500  Indian Rupees(Rs.)
# 3                      400  Indian Rupees(Rs.)
# 4                     1000  Indian Rupees(Rs.)
# ...                    ...                 ...
# 9546                    10           Dollar($)
# 9547                    10           Dollar($)
# 9548                    25           Dollar($)
# 9549                    25           Dollar($)
# 9550                    25           Dollar($)
#
# [9551 rows x 2 columns]

# %%
df['Currency'].unique()
# Out:
# array(['Indian Rupees(Rs.)', 'Dollar($)', 'Brazilian Real(R$)',
#        'Indonesian Rupiah(IDR)', 'NewZealand($)', 'Botswana Pula(P)',
#        'Qatari Rial(QR)', 'Rand(R)', 'Sri Lankan Rupee(LKR)',
#        'Turkish Lira(TL)', 'Emirati Diram(AED)', 'Pounds(\x8c£)'],
#       dtype=object)

# %% [markdown]
# as per considering rate on date 19th october 2023 we convert all curreny to indian rupees.
# 1 Dollar($)              = 83.27 Indian Rupees(Rs.)
#
# 1 Brazilian Real(R$)     = 16.46 Indian Rupees(Rs.)
#
# 1 Indonesian Rupiah(IDR) = 0.0053 Indian Rupees(Rs.)
#
# 1 NewZealand($)          = 48.46 Indian Rupees(Rs.)
#
# 1 Botswana Pula(P)       = 6.08 Indian Rupees(Rs.)
#
# 1 Qatari Rial(QR)        = 22.87 Indian Rupees(Rs.)
#
# 1 Rand(R)                = 4.35 Indian Rupees(Rs.)
#
# 1 Sri Lankan Rupee(LKR)  = 0.26 Indian Rupees(Rs.)
#
# 1 Turkish Lira(TL)       = 2.97 Indian Rupees(Rs.)
#
# 1 Emirati Diram(AED)     = 22.67 Indian Rupees(Rs.)
#
# 1 Pounds(\x8c£)          = 100.8 Indian Rupees(Rs.)

# %%
df.loc[df['Currency'] == 'Dollar($)', 'Average Cost for two'] *= 83.27
df.loc[df['Currency'] == 'Brazilian Real(R$)', 'Average Cost for two'] *= 16.46
df.loc[df['Currency'] == 'Indonesian Rupiah(IDR)', 'Average Cost for two'] *= 0.0053
df.loc[df['Currency'] == 'NewZealand($)', 'Average Cost for two'] *= 48.46
df.loc[df['Currency'] == 'Botswana Pula(P)', 'Average Cost for two'] *= 6.08
df.loc[df['Currency'] == 'Qatari Rial(QR)', 'Average Cost for two'] *= 22.87
df.loc[df['Currency'] == 'Rand(R)', 'Average Cost for two'] *= 4.35
df.loc[df['Currency'] == 'Sri Lankan Rupee(LKR)', 'Average Cost for two'] *= 0.26
df.loc[df['Currency'] == 'Turkish Lira(TL)', 'Average Cost for two'] *= 2.97
df.loc[df['Currency'] == 'Emirati Diram(AED)', 'Average Cost for two'] *= 22.67
df.loc[df['Currency'] == 'Pounds(\x8c£)', 'Average Cost for two'] *= 100.8

# %%
df[['Average Cost for two','Currency']]
# Out:
#       Average Cost for two            Currency
# 0                   850.00  Indian Rupees(Rs.)
# 1                   700.00  Indian Rupees(Rs.)
# 2                   500.00  Indian Rupees(Rs.)
# 3                   400.00  Indian Rupees(Rs.)
# 4                  1000.00  Indian Rupees(Rs.)
# ...                    ...                 ...
# 9546                832.70           Dollar($)
# 9547                832.70           Dollar($)
# 9548               2081.75           Dollar($)
# 9549               2081.75           Dollar($)
# 9550               2081.75           Dollar($)
#
# [9551 rows x 2 columns]

# %%
df
# Out:
#       Country Code        Country  Restaurant ID  \
# 0                1          India        3400025
# 1                1          India        3400341
# 2                1          India        3400005
# 3                1          India        3400021
# 4                1          India        3400017
# ...            ...            ...            ...
# 9546           216  United States       17697389
# 9547           216  United States       17697424
# 9548           216  United States       17697332
# 9549           216  United States       17694056
# 9550           216  United States       17559793
#
#                                Restaurant Name            City  \
# 0                                   Jahanpanah            Agra
# 1                          Rangrezz Restaurant            Agra
# 2                      Time2Eat - Mama Chicken            Agra
# 3        Chokho Jeeman Marwari Jain Bhojanalya            Agra
# ...

# %%
plt.figure(figsize=(15, 6))
sns.barplot(df['Rating text'],df['Average Cost for two'])
# Out:
# <AxesSubplot:xlabel='Rating text', ylabel='Average Cost for two'>

# %% [markdown]
# As restraunt increases rating it also increse average cost of two persons also, excellent rated restraunt has the highest average cost is which is around 2500+(INR), then very good rated restraunt cost 1500+(INR) and good rate cost is 1000+(INR) and avearge restraunt cost is 500+(INR).

# %%
plt.figure(figsize=(15, 25))
sns.barplot(df['Price range'],df['City'])
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='City'>

# %%
df['City'].unique
# Out:
# <bound method Series.unique of 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#        ...
# 9546    135
# 9547    135
# 9548    135
# 9549    136
# 9550    138
# Name: City, Length: 9551, dtype: int32>

# %% [markdown]
# we can see list of cities of its restraunts price range of each,
# johannesburg, inner city, princeton,pasay city , vineland station,paynesvelle, panchkula are the highest costiest city restraunt.

# %%
plt.figure(figsize=(15, 15))
sns.barplot(df['Average Cost for two'],df['Country'])
# Out:
# <AxesSubplot:xlabel='Average Cost for two', ylabel='Country'>

# %% [markdown]
# Singspore has costiliest restraunt which has price is 12500+(INR) and second costliest is phillipines restraunt and , most cheap restraunt are in Turkey, then Sri lanka and India.

# %%
df['Cuisines'].value_counts()
# Out:
# North Indian                                 936
# North Indian, Chinese                        511
# Fast Food                                    354
# Chinese                                      354
# North Indian, Mughlai                        334
#                                             ...
# Cafe, Mexican, Continental                     1
# North Indian, Continental, Asian, Italian      1
# Continental, Cafe                              1
# North Indian, Biryani, Mughlai                 1
# Burger, Greek, Sandwich                        1
# Name: Cuisines, Length: 1825, dtype: int64

# %% [markdown]
# 936 restraunt has North indian specific food in their cuisine which has highest single cuisine in restraunt list.

# %%
sns.displot(df['Average Cost for two'],bins=50)

# %%
sns.displot(df['Is delivering now'],bins=50)

# %%
df.skew()
# Out:
# Country Code             3.043965
# Restaurant ID            0.061570
# Longitude               -2.807328
# Latitude                -3.081635
# Average Cost for two    11.477702
# Price range              0.889618
# Aggregate rating        -0.954130
# Votes                    8.807637
# dtype: float64

# %% [markdown]
# Votes data are skewed.

# %%
df['Votes'] = np.sqrt(df['Votes'])

# %% [markdown]
# we reduced skewness of Votes column data.

# %%
df['Average Cost for two'].unique()
# Out:
# array([  850.  ,   700.  ,   500.  ,   400.  ,  1000.  ,  2000.  ,
#         2500.  ,   800.  ,  3600.  ,     0.  ,   550.  ,  1100.  ,
#         1500.  ,   900.  ,  1800.  ,   300.  ,  1400.  ,   350.  ,
#          450.  ,   600.  ,   950.  ,  1200.  ,   200.  ,   100.  ,
#          150.  ,   650.  ,  1300.  ,  2400.  ,   250.  ,  1600.  ,
#         2200.  ,   750.  ,  1700.  ,  1250.  ,  1900.  ,  2700.  ,
#         3500.  ,  5000.  ,  2300.  ,  1750.  ,  3200.  ,  3000.  ,
#         2100.  ,  1850.  ,  4500.  ,  4000.  ,  3300.  ,   120.  ,
#         1350.  ,  1650.  ,  1950.  ,  1050.  ,   290.  ,    50.  ,
#         1450.  ,  2800.  ,   260.  ,  3650.  ,  4800.  ,  1550.  ,
#          720.  ,  6500.  ,  7000.  ,  1150.  ,  2900.  ,  2600.  ,
#         4700.  ,  3700.  ,  3800.  ,  4100.  ,  4300.  ,  2650.  ,
#         6000.  ,  5100.  ,  5500.  ,  4400.  ,  4200.  ,  8000.  ,
#         2350.  ,  1665.4 ,   582.89,  2498.1 ,  9992.4 ,   905.3 ,
# ...

# %%
df.skew()
# Out:
# Country Code             3.043965
# Restaurant ID            0.061570
# Longitude               -2.807328
# Latitude                -3.081635
# Average Cost for two    11.477702
# Price range              0.889618
# Aggregate rating        -0.954130
# Votes                    2.518922
# dtype: float64

# %%
plt.figure(figsize=(8,4))
sns.heatmap(df.corr(),cmap='OrRd',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Votes are highly postive co relate with aggregate rating, also potive co relate with price range.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country Code          9551 non-null   int64
#  1   Country               9551 non-null   object
#  2   Restaurant ID         9551 non-null   int64
#  3   Restaurant Name       9551 non-null   object
#  4   City                  9551 non-null   object
#  5   Address               9551 non-null   object
#  6   Locality              9551 non-null   object
#  7   Locality Verbose      9551 non-null   object
#  8   Longitude             9551 non-null   float64
#  9   Latitude              9551 non-null   float64
#  10  Cuisines              9542 non-null   object
#  11  Average Cost for two  9551 non-null   float64
#  12  Currency              9551 non-null   object
#  13  Has Table booking     9551 non-null   object
#  14  Has Online delivery   9551 non-null   object
# ...

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
df.describe()
# Out:
#        Country Code  Restaurant ID    Longitude     Latitude  \
# count   9551.000000   9.551000e+03  9551.000000  9551.000000
# mean      18.365616   9.051128e+06    64.126574    25.854381
# std       56.750546   8.791521e+06    41.467058    11.007935
# min        1.000000   5.300000e+01  -157.948486   -41.330428
# 25%        1.000000   3.019625e+05    77.081343    28.478713
# 50%        1.000000   6.004089e+06    77.191964    28.570469
# 75%        1.000000   1.835229e+07    77.282006    28.642758
# max      216.000000   1.850065e+07   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating        Votes
# count           9551.000000  9551.000000       9551.000000  9551.000000
# mean             839.415926     1.804837          2.666370     8.375049
# std             1391.069027     0.905609          1.516378     9.315438
# min                0.000000     1.000000          0.000000     0.000000
# ...

# %%
df.plot(kind='box', subplots=True, layout=(2, 6), figsize=(10, 10))
# Out:
# Country Code               AxesSubplot(0.125,0.53;0.110714x0.35)
# Restaurant ID           AxesSubplot(0.257857,0.53;0.110714x0.35)
# Longitude               AxesSubplot(0.390714,0.53;0.110714x0.35)
# Latitude                AxesSubplot(0.523571,0.53;0.110714x0.35)
# Average Cost for two    AxesSubplot(0.656429,0.53;0.110714x0.35)
# Price range             AxesSubplot(0.789286,0.53;0.110714x0.35)
# Aggregate rating           AxesSubplot(0.125,0.11;0.110714x0.35)
# Votes                   AxesSubplot(0.257857,0.11;0.110714x0.35)
# dtype: object

# %%
sns.pairplot(df)

# %%
df=df.drop(['Longitude','Latitude','Locality Verbose','Restaurant Name','Address','Currency','Rating color','Rating text','Switch to order menu'],axis=1)

# %%
df
# Out:
#       Country Code        Country  Restaurant ID            City  \
# 0                1          India        3400025            Agra
# 1                1          India        3400341            Agra
# 2                1          India        3400005            Agra
# 3                1          India        3400021            Agra
# 4                1          India        3400017            Agra
# ...            ...            ...            ...             ...
# 9546           216  United States       17697389        Waterloo
# 9547           216  United States       17697424        Waterloo
# 9548           216  United States       17697332        Waterloo
# 9549           216  United States       17694056         Weirton
# 9550           216  United States       17559793  Winchester Bay
#
#             Locality                        Cuisines  Average Cost for two  \
# 0         Agra Cantt           North Indian, Mughlai                850.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country Code          9551 non-null   int64
#  1   Country               9551 non-null   object
#  2   Restaurant ID         9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Locality              9551 non-null   object
#  5   Cuisines              9542 non-null   object
#  6   Average Cost for two  9551 non-null   float64
#  7   Has Table booking     9551 non-null   object
#  8   Has Online delivery   9551 non-null   object
#  9   Is delivering now     9551 non-null   object
#  10  Price range           9551 non-null   int64
#  11  Aggregate rating      9551 non-null   float64
#  12  Votes                 9551 non-null   float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 1.3+ MB

# %%
le = LabelEncoder()
df['Country'] = le.fit_transform(df['Country'])
df['City'] = le.fit_transform(df['City'])
df['Locality'] = le.fit_transform(df['Locality'])
df['Cuisines'] = le.fit_transform(df['Cuisines'])
df['Has Table booking'] = le.fit_transform(df['Has Table booking'])
df['Has Online delivery'] = le.fit_transform(df['Has Online delivery'])
df['Is delivering now'] = le.fit_transform(df['Is delivering now'])

# %% [markdown]
# with label encoder we string data in numeric for our model.

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
#       Country Code   Country  Restaurant ID      City  Locality  Cuisines  \
# 0         0.306015  0.277839       0.642824  3.332289  2.029851  1.018171
# 1         0.306015  0.277839       0.642788  3.332289  2.029851  1.018171
# 2         0.306015  0.277839       0.642826  3.332289  2.029851  0.614050
# 3         0.306015  0.277839       0.642824  3.332289  1.437798  1.272690
# 4         0.306015  0.277839       0.642825  3.332289  1.437798  0.744223
# ...            ...       ...            ...       ...       ...       ...
# 9546      3.482693  3.870249       0.983529  2.444146  1.633280  1.888396
# 9547      3.482693  3.870249       0.983533  2.444146  1.633280  1.564124
# 9548      3.482693  3.870249       0.983522  2.444146  1.633280  0.262386
# 9549      3.482693  3.870249       0.983150  2.487254  1.639612  1.307471
# 9550      3.482693  3.870249       0.967877  2.573469  1.671273  1.288042
#
#       Average Cost for two  Has Table booking  Has Online delivery  \
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([   0,    1,    2, ..., 9549, 9550, 9550], dtype=int64), array([3, 3, 3, ..., 1, 0, 1], dtype=int64))

# %% [markdown]
# here we remove outliers and saved in different dataframe for better model perfomance.

# %%
df3=df[(z<3).all(axis=1)]

# %%
df3
# Out:
#       Country Code  Country  Restaurant ID  City  Locality  Cuisines  \
# 82               1        3        2500023    11        19      1338
# 83               1        3        2500076    11       187      1049
# 84               1        3        2500054    11       150      1329
# 85               1        3        2500134    11       150      1618
# 86               1        3        2500069    11       150      1554
# ...            ...      ...            ...   ...       ...       ...
# 8854           184        8       18493989   118       645      1697
# 8857           184        8       18482983   118       707      1696
# 8858           184        8       18479742   118       722      1821
# 8860           184        8       18483082   118      1026        17
# 8861           184        8       18483446   118      1050       895
#
#       Average Cost for two  Has Table booking  Has Online delivery  \
# 82                   800.0                  0                    0
# ...

# %%
df['Is delivering now'].unique()
# Out:
# array([0, 1])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country Code          9551 non-null   int64
#  1   Country               9551 non-null   int32
#  2   Restaurant ID         9551 non-null   int64
#  3   City                  9551 non-null   int32
#  4   Locality              9551 non-null   int32
#  5   Cuisines              9551 non-null   int32
#  6   Average Cost for two  9551 non-null   float64
#  7   Has Table booking     9551 non-null   int32
#  8   Has Online delivery   9551 non-null   int32
#  9   Is delivering now     9551 non-null   int32
#  10  Price range           9551 non-null   int64
#  11  Aggregate rating      9551 non-null   float64
#  12  Votes                 9551 non-null   float64
# dtypes: float64(3), int32(7), int64(3)
# memory usage: 1.0 MB

# %%
df3.insert(12, 'Average Cost for two', df3.pop('Average Cost for two'))

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df3.corr(),cmap='OrRd',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Average cost of two are highly positive co related with price range.
# Average cost of two are positive co relate with votes, rating and if it has table booking also.
# rating and price range also positive co relate.

# %% [markdown]
# # Here we make model to find predict average cost of two persons.

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier,AdaBoostClassifier, GradientBoostingClassifier, BaggingClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.svm import SVC

# %%
x = df3.iloc[:,1:2].join(df3.iloc[:, 3:12])

# %%
y=df3.iloc[:,-1]

# %%
x.head()
# Out:
#     Country  City  Locality  Cuisines  Has Table booking  Has Online delivery  \
# 82        3    11        19      1338                  0                    0
# 83        3    11       187      1049                  0                    0
# 84        3    11       150      1329                  0                    0
# 85        3    11       150      1618                  0                    0
# 86        3    11       150      1554                  0                    0
#
#     Is delivering now  Price range  Aggregate rating      Votes
# 82                  0            3               3.6  15.491933
# 83                  0            3               3.3   8.062258
# 84                  0            2               3.3   7.937254
# 85                  0            2               3.1   4.358899
# 86                  0            2               3.4   6.782330

# %%
y.head()
# Out:
# 82    800.0
# 83    850.0
# 84    600.0
# 85    700.0
# 86    350.0
# Name: Average Cost for two, dtype: float64

# %%
#st=StandardScaler()
#x=st.fit_transform(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=50)

# %%
lm = LinearRegression()
lm.fit(x_train, y_train)
lm.score(x_train,y_train)
# Out:
# 0.7200993869347498

# %% [markdown]
# Linear Regression has model accuracy is 72 %.

# %%
from sklearn.linear_model import Lasso,Ridge

# %%
ls=Lasso(alpha=0.001)
ls.fit(x_train,y_train)
print(ls.score(x_train,y_train))
# Out:
# 0.7200993868667421

# %% [markdown]
# Lasso model has accuracy score is 72%

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)


preddtr=dtr.predict(x_test)
print('DTR score :',dtr.score(x_train,y_train))
print('DTR r2_score:',r2_score(y_test,preddtr))
# Out:
# DTR score : 0.9996693833608732
# DTR r2_score: 0.7700078380210175

# %% [markdown]
# Decision tree regressor model score is 99.96%.

# %%
from sklearn.svm import SVR

# %%
svr=SVR ()
svr.fit(x_train,y_train)
print(svr.score(x_train,y_train))
pred_y=svr.predict(x_test)
pred_y
print('Mean Squared error :',np.sqrt(mean_squared_error(y_test,pred_y)))

svr=SVR (kernel='poly')
svr.fit(x_train,y_train)
print(svr.score(x_train,y_train))
pred_y=svr.predict(x_test)
pred_y
print('Mean Squared error :',np.sqrt(mean_squared_error(y_test,pred_y)))

svr=SVR (kernel='rbf')
svr.fit(x_train,y_train)
print(svr.score(x_train,y_train))
pred_y=svr.predict(x_test)
pred_y
print('Mean Squared error :',np.sqrt(mean_squared_error(y_test,pred_y)))
# Out:
# -0.07198435454906127
# Mean Squared error : 646.4425676444068
# -0.0756401977125003
# Mean Squared error : 648.0069867717029
# -0.07198435454906127
# Mean Squared error : 646.4425676444068

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knr=KNeighborsRegressor()
knr.fit(x_train,y_train)
print('knr score',knr.score(x_train,y_train))


mse = mean_squared_error(y_test, preddtr)
r2 = r2_score(y_test, preddtr)
print("r2 Score:", r2)
# Out:
# knr score 0.5089467040997973
# r2 Score: 0.7700078380210175

# %% [markdown]
# KNeighborsRegressor model score is 50%.

# %%
from sklearn.ensemble import RandomForestRegressor

rf=RandomForestRegressor(n_estimators=100,random_state=42)
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print('Rf score :',rf.score(x_train,y_train))
print('rf r2_score:',r2_score(y_test,predrf))
# Out:
# Rf score : 0.9806455468314365
# rf r2_score: 0.8641649622572469

# %% [markdown]
# RandomForestRegressor model score is 98%.

# %%
from sklearn.ensemble import AdaBoostRegressor

ada=AdaBoostRegressor(n_estimators=100,random_state=42)
ada.fit(x_train,y_train)
predada=ada.predict(x_test)
print('Ada score :',ada.score(x_train,y_train))
print('Ada r2_score:',r2_score(y_test,predada))
# Out:
# Ada score : 0.7630456205162852
# Ada r2_score: 0.7376924968919942

# %% [markdown]
# AdaBoostRegressor model has score is 76%.

# %%
from sklearn.ensemble import GradientBoostingRegressor

Gbr=GradientBoostingRegressor()
Gbr.fit(x_train,y_train)
predGbr=Gbr.predict(x_test)
print('Gbr score :',Gbr.score(x_train,y_train))
print('Gbr r2_score:',r2_score(y_test,predGbr))
# Out:
# Gbr score : 0.9062932494555717
# Gbr r2_score: 0.8607210536113438

# %% [markdown]
# GradientBoostingRegressor model score is 90%.

# %%
import joblib 

joblib.dump(preddtr, 'Cost_For_Two.pkl')
# Out:
# ['Cost_For_Two.pkl']

# %% [markdown]
# We saved the best model decision tree regressor which has highest score 99.96%.

# %% [markdown]
# # Here we make model to find predict price range.

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8519 entries, 82 to 8861
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country Code          8519 non-null   int64
#  1   Country               8519 non-null   int32
#  2   Restaurant ID         8519 non-null   int64
#  3   City                  8519 non-null   int32
#  4   Locality              8519 non-null   int32
#  5   Cuisines              8519 non-null   int32
#  6   Has Table booking     8519 non-null   int32
#  7   Has Online delivery   8519 non-null   int32
#  8   Is delivering now     8519 non-null   int32
#  9   Price range           8519 non-null   int64
#  10  Aggregate rating      8519 non-null   float64
#  11  Votes                 8519 non-null   float64
#  12  Average Cost for two  8519 non-null   float64
# dtypes: float64(3), int32(7), int64(3)
# memory usage: 956.9 KB

# %%
x = df3.iloc[:,1:2].join(df3.iloc[:, 3:9]).join(df3.iloc[:, 10:12])

# %%
y=df3.iloc[:,9:10]

# %%
x.head()
# Out:
#     Country  City  Locality  Cuisines  Has Table booking  Has Online delivery  \
# 82        3    11        19      1338                  0                    0
# 83        3    11       187      1049                  0                    0
# 84        3    11       150      1329                  0                    0
# 85        3    11       150      1618                  0                    0
# 86        3    11       150      1554                  0                    0
#
#     Is delivering now  Aggregate rating      Votes
# 82                  0               3.6  15.491933
# 83                  0               3.3   8.062258
# 84                  0               3.3   7.937254
# 85                  0               3.1   4.358899
# 86                  0               3.4   6.782330

# %%
y.head()
# Out:
#     Price range
# 82            3
# 83            3
# 84            2
# 85            2
# 86            2

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=50)

# %%
lg = LogisticRegression()
lg.fit(x_train, y_train)
predlg=lg.predict(x_test)
print(accuracy_score(y_test,predlg))
print(confusion_matrix(y_test,predlg))
print(classification_report(y_test,predlg))
# Out:
# 0.6
# [[832 111  12   0]
#  [336 246  32   0]
#  [ 55 113  47   0]
#  [ 36  44  11   0]]
#               precision    recall  f1-score   support
#
#            1       0.66      0.87      0.75       955
#            2       0.48      0.40      0.44       614
#            3       0.46      0.22      0.30       215
#            4       0.00      0.00      0.00        91
#
#     accuracy                           0.60      1875
#    macro avg       0.40      0.37      0.37      1875
# weighted avg       0.55      0.60      0.56      1875

# %% [markdown]
# Logistic regression model has accuracy of 60%.

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc=dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 0.6234666666666666
# [[717 215  18   5]
#  [215 304  81  14]
#  [ 11  57 113  34]
#  [  9  12  35  35]]
#               precision    recall  f1-score   support
#
#            1       0.75      0.75      0.75       955
#            2       0.52      0.50      0.51       614
#            3       0.46      0.53      0.49       215
#            4       0.40      0.38      0.39        91
#
#     accuracy                           0.62      1875
#    macro avg       0.53      0.54      0.53      1875
# weighted avg       0.62      0.62      0.62      1875

# %% [markdown]
# DecisionTreeClassifier model has accuracy of 62%.

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
predknn=knn.predict(x_test)
print(accuracy_score(y_test,predknn))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 0.6170666666666667
# [[717 215  18   5]
#  [215 304  81  14]
#  [ 11  57 113  34]
#  [  9  12  35  35]]
#               precision    recall  f1-score   support
#
#            1       0.75      0.75      0.75       955
#            2       0.52      0.50      0.51       614
#            3       0.46      0.53      0.49       215
#            4       0.40      0.38      0.39        91
#
#     accuracy                           0.62      1875
#    macro avg       0.53      0.54      0.53      1875
# weighted avg       0.62      0.62      0.62      1875

# %% [markdown]
# KNeighborsClassifier has accuracy score is 61%.

# %%
RFC = RandomForestClassifier()
RFC.fit(x_train, y_train)
predRFC = RFC.predict(x_test)
print(accuracy_score(y_test, predRFC))
print(confusion_matrix(y_test,predRFC))
print(classification_report(y_test,predRFC))
# Out:
# 0.7088
# [[809 138   8   0]
#  [213 351  46   4]
#  [ 14  48 138  15]
#  [  9  11  40  31]]
#               precision    recall  f1-score   support
#
#            1       0.77      0.85      0.81       955
#            2       0.64      0.57      0.60       614
#            3       0.59      0.64      0.62       215
#            4       0.62      0.34      0.44        91
#
#     accuracy                           0.71      1875
#    macro avg       0.66      0.60      0.62      1875
# weighted avg       0.70      0.71      0.70      1875

# %% [markdown]
# RandomForestClassifier has accuracy score is 70%.

# %%
ad=AdaBoostClassifier()
ad.fit(x_train,y_train)
ad_pred=ad.predict(x_test)
print(accuracy_score(y_test,ad_pred))
print(confusion_matrix(y_test,ad_pred))
print(classification_report(y_test,ad_pred))
# Out:
# 0.6490666666666667
# [[846 105   4   0]
#  [316 233  51  14]
#  [ 15  46  89  65]
#  [ 11  12  19  49]]
#               precision    recall  f1-score   support
#
#            1       0.71      0.89      0.79       955
#            2       0.59      0.38      0.46       614
#            3       0.55      0.41      0.47       215
#            4       0.38      0.54      0.45        91
#
#     accuracy                           0.65      1875
#    macro avg       0.56      0.55      0.54      1875
# weighted avg       0.64      0.65      0.63      1875

# %% [markdown]
# AdaBoostClassifier model has accuracy score is 64%.

# %%
GB = GradientBoostingClassifier()
GB.fit(x_train, y_train)
predGB = GB.predict(x_test)
print(accuracy_score(y_test, predGB))
print(confusion_matrix(y_test,predGB))
print(classification_report(y_test,predGB))
# Out:
# 0.7306666666666667
# [[835 116   4   0]
#  [201 362  45   6]
#  [ 10  49 144  12]
#  [  7   9  46  29]]
#               precision    recall  f1-score   support
#
#            1       0.79      0.87      0.83       955
#            2       0.68      0.59      0.63       614
#            3       0.60      0.67      0.63       215
#            4       0.62      0.32      0.42        91
#
#     accuracy                           0.73      1875
#    macro avg       0.67      0.61      0.63      1875
# weighted avg       0.72      0.73      0.72      1875

# %% [markdown]
# GradientBoostingClassifier model has accuracy score is 73%.

# %%
BC = BaggingClassifier()
BC.fit(x_train, y_train)
predBC = BC.predict(x_test)
print(accuracy_score(y_test, predBC))
print(confusion_matrix(y_test,predBC))
print(classification_report(y_test,predBC))
# Out:
# 0.6922666666666667
# [[803 143   8   1]
#  [219 334  56   5]
#  [ 12  62 130  11]
#  [  9  20  31  31]]
#               precision    recall  f1-score   support
#
#            1       0.77      0.84      0.80       955
#            2       0.60      0.54      0.57       614
#            3       0.58      0.60      0.59       215
#            4       0.65      0.34      0.45        91
#
#     accuracy                           0.69      1875
#    macro avg       0.65      0.58      0.60      1875
# weighted avg       0.69      0.69      0.69      1875

# %% [markdown]
# BaggingClassifier model has accuracy score is 69%.

# %%
ETC = ExtraTreesClassifier()
ETC.fit(x_train, y_train)
predETC = ETC.predict(x_test)
print(accuracy_score(y_test, predETC))
print(confusion_matrix(y_test,predETC))
print(classification_report(y_test,predETC))
# Out:
# 0.6805333333333333
# [[773 175   7   0]
#  [232 334  44   4]
#  [ 16  48 133  18]
#  [  8  11  36  36]]
#               precision    recall  f1-score   support
#
#            1       0.75      0.81      0.78       955
#            2       0.59      0.54      0.57       614
#            3       0.60      0.62      0.61       215
#            4       0.62      0.40      0.48        91
#
#     accuracy                           0.68      1875
#    macro avg       0.64      0.59      0.61      1875
# weighted avg       0.67      0.68      0.68      1875

# %% [markdown]
# ExtraTreesClassifier model has accuracy score is 68%.

# %%
gnb = GaussianNB()
gnb.fit(x_train, y_train)
predgnb = gnb.predict(x_test)
print(accuracy_score(y_test, predgnb))
print(confusion_matrix(y_test,predgnb))
print(classification_report(y_test,predgnb))
# Out:
# 0.6261333333333333
# [[926  21   8   0]
#  [464  88  54   8]
#  [ 52  16 132  15]
#  [ 14   9  40  28]]
#               precision    recall  f1-score   support
#
#            1       0.64      0.97      0.77       955
#            2       0.66      0.14      0.24       614
#            3       0.56      0.61      0.59       215
#            4       0.55      0.31      0.39        91
#
#     accuracy                           0.63      1875
#    macro avg       0.60      0.51      0.50      1875
# weighted avg       0.63      0.63      0.55      1875

# %% [markdown]
# GaussianNB model has accuracy score is 62%.

# %%
svc = SVC(kernel='poly')
svc.fit(x_train, y_train)
predsvc = svc.predict(x_test)
print(accuracy_score(y_test, predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.5093333333333333
# [[955   0   0   0]
#  [614   0   0   0]
#  [214   1   0   0]
#  [ 91   0   0   0]]
#               precision    recall  f1-score   support
#
#            1       0.51      1.00      0.68       955
#            2       0.00      0.00      0.00       614
#            3       0.00      0.00      0.00       215
#            4       0.00      0.00      0.00        91
#
#     accuracy                           0.51      1875
#    macro avg       0.13      0.25      0.17      1875
# weighted avg       0.26      0.51      0.34      1875

# %% [markdown]
# SVC model has accuracy score is 50%.

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(GB,x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.4084507  0.47359155 0.60680751 0.68309859 0.61890781]
# 0.5581712333110033
# 0.10122373625841777

# %% [markdown]
# here we save best model GradientBoostingClassifier which has highest accuracy which is 73%.

# %%
joblib.dump(preddtr, 'GB.pkl')
# Out:
# ['GB.pkl']
