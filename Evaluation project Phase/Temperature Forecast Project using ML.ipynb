# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Dataset2/main/temperature.csv")

# %%
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# ...

# %%
df.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %% [markdown]
# here we can see so many column has null values.

# %%
df1 = df.dropna(subset=['LDAPS_WS','Next_Tmax','Present_Tmax','station'], axis=0)

# %% [markdown]
# so here we drop raw for above column has nan values.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7588 entries, 0 to 7749
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7588 non-null   float64
#  1   Date              7588 non-null   object
#  2   Present_Tmax      7588 non-null   float64
#  3   Present_Tmin      7588 non-null   float64
#  4   LDAPS_RHmin       7588 non-null   float64
#  5   LDAPS_RHmax       7588 non-null   float64
#  6   LDAPS_Tmax_lapse  7588 non-null   float64
#  7   LDAPS_Tmin_lapse  7588 non-null   float64
#  8   LDAPS_WS          7588 non-null   float64
#  9   LDAPS_LH          7588 non-null   float64
#  10  LDAPS_CC1         7588 non-null   float64
#  11  LDAPS_CC2         7588 non-null   float64
#  12  LDAPS_CC3         7588 non-null   float64
#  13  LDAPS_CC4         7588 non-null   float64
#  14  LDAPS_PPT1        7588 non-null   float64
#  15  LDAPS_PPT2        7588 non-null   float64
# ...

# %% [markdown]
# now our data is clean and perfect as there is no null values.

# %%
df1['Date'] = pd.to_datetime(df1.Date, format='%d-%m-%Y')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7588 entries, 0 to 7749
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7588 non-null   float64
#  1   Date              7588 non-null   datetime64[ns]
#  2   Present_Tmax      7588 non-null   float64
#  3   Present_Tmin      7588 non-null   float64
#  4   LDAPS_RHmin       7588 non-null   float64
#  5   LDAPS_RHmax       7588 non-null   float64
#  6   LDAPS_Tmax_lapse  7588 non-null   float64
#  7   LDAPS_Tmin_lapse  7588 non-null   float64
#  8   LDAPS_WS          7588 non-null   float64
#  9   LDAPS_LH          7588 non-null   float64
#  10  LDAPS_CC1         7588 non-null   float64
#  11  LDAPS_CC2         7588 non-null   float64
#  12  LDAPS_CC3         7588 non-null   float64
#  13  LDAPS_CC4         7588 non-null   float64
#  14  LDAPS_PPT1        7588 non-null   float64
#  15  LDAPS_PPT2        7588 non-null   float64
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df1.corr(),cmap='GnBu',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# from above we co relation chart here below some points which we need to look at :-
#     1) LDAPS first and last 6 hour prediction for cloud cover is highly match with next day actual temperature compare to middle 12 hours pridection.
#     2) Humidity is highly co relate with temperature.
#     3) LDAPS first and last 6 hour prediction for precipitation  is highly match with next day actual temperature compare to middle 12 hours pridection.

# %%
sns.countplot(df1['station'])
# Out:
# <AxesSubplot:xlabel='station', ylabel='count'>

# %%
here as per above chart we can say there is 25 stations which record temperature, and each station count around 300 times.

# %%
plt.scatter(df1['LDAPS_CC1'],df1['LDAPS_PPT1'])

# %% [markdown]
# as from above chart we notice as precipitation increase then cloud cover is also increases.

# %%
plt.violinplot(df1['Present_Tmax'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x173e19e5e50>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x173e1a0df10>,
#  'cmins': <matplotlib.collections.LineCollection at 0x173e18a7730>,
#  'cbars': <matplotlib.collections.LineCollection at 0x173e18a7af0>}

# %% [markdown]
# as from above chart we can see 30 degree celsius is highesy frequency, it means 30 to 28 degree temperture is the most of days temperature.

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df1.iloc[:,1:3])
# Out:
# <AxesSubplot:>

# %%
sns.lmplot(x='Present_Tmax',y='LDAPS_Tmax_lapse',data=df1)

# %%
plt.figure(figsize=(12, 6))
plt.plot(df1['Date'], df1['Present_Tmax'], label='Present_Tmax', marker='o')
plt.plot(df1['Date'], df1['LDAPS_Tmax_lapse'], label='LDAPS_Tmax_lapse', marker='x')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# as from above chart we can see 2013 has lowest temperature around 22.5 degree but for 2016 it has almost 20 degree.
# as compare to max temperature it is incresing gradualy from 2013 to 2016 , just little come down on 2017.

# %%
df1.skew()
# Out:
# station            -0.004178
# Present_Tmax       -0.257069
# Present_Tmin       -0.353822
# LDAPS_RHmin         0.301396
# LDAPS_RHmax        -0.845264
# LDAPS_Tmax_lapse   -0.222349
# LDAPS_Tmin_lapse   -0.574035
# LDAPS_WS            1.553926
# LDAPS_LH            0.662971
# LDAPS_CC1           0.456716
# LDAPS_CC2           0.473929
# LDAPS_CC3           0.639649
# LDAPS_CC4           0.663815
# LDAPS_PPT1          5.305906
# LDAPS_PPT2          5.710360
# LDAPS_PPT3          6.356670
# LDAPS_PPT4          6.681256
# lat                 0.085377
# lon                -0.289048
# DEM                 1.721617
# Slope               1.559050
# Solar radiation    -0.524325
# Next_Tmax          -0.334842
# Next_Tmin          -0.393662
# dtype: float64

# %% [markdown]
# as we see there is skewness in some column so for our model better performance we remove skewness.

# %%
df1['LDAPS_PPT1']=np.cbrt(df1['LDAPS_PPT1'])
df1['LDAPS_PPT2']=np.cbrt(df1['LDAPS_PPT2'])
df1['LDAPS_PPT3']=np.cbrt(df1['LDAPS_PPT3'])
df1['LDAPS_PPT4']=np.cbrt(df1['LDAPS_PPT4'])

# %%
df1.skew()
# Out:
# station            -0.004178
# Present_Tmax       -0.257069
# Present_Tmin       -0.353822
# LDAPS_RHmin         0.301396
# LDAPS_RHmax        -0.845264
# LDAPS_Tmax_lapse   -0.222349
# LDAPS_Tmin_lapse   -0.574035
# LDAPS_WS            1.553926
# LDAPS_LH            0.662971
# LDAPS_CC1           0.456716
# LDAPS_CC2           0.473929
# LDAPS_CC3           0.639649
# LDAPS_CC4           0.663815
# LDAPS_PPT1          1.955868
# LDAPS_PPT2          2.267487
# LDAPS_PPT3          2.575795
# LDAPS_PPT4          2.837790
# lat                 0.085377
# lon                -0.289048
# DEM                 1.721617
# Slope               1.559050
# Solar radiation    -0.524325
# Next_Tmax          -0.334842
# Next_Tmin          -0.393662
# dtype: float64

# %%
df1.set_index('Date', inplace=True)

# %%
df1
# Out:
#             station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# Date
# 2013-06-30      1.0          28.7          21.4    58.255688    91.116364
# 2013-06-30      2.0          31.9          21.6    52.263397    90.604721
# 2013-06-30      3.0          31.6          23.3    48.690479    83.973587
# 2013-06-30      4.0          32.0          23.4    58.239788    96.483688
# 2013-06-30      5.0          31.4          21.9    56.174095    90.155128
# ...             ...           ...           ...          ...          ...
# 2017-08-30     21.0          23.1          17.8    24.688997    78.261383
# 2017-08-30     22.0          22.5          17.4    30.094858    83.690018
# 2017-08-30     23.0          23.3          17.1    26.741310    78.869858
# 2017-08-30     24.0          23.3          17.7    24.040634    77.294975
# 2017-08-30     25.0          23.2          17.4    22.933014    77.243744
#
#             LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  \
# ...

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
x=df1.iloc[:,0:22]
y=df1.iloc[:,-2]

# %%
x.head()
# Out:
#             station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# Date
# 2013-06-30      1.0          28.7          21.4    58.255688    91.116364
# 2013-06-30      2.0          31.9          21.6    52.263397    90.604721
# 2013-06-30      3.0          31.6          23.3    48.690479    83.973587
# 2013-06-30      4.0          32.0          23.4    58.239788    96.483688
# 2013-06-30      5.0          31.4          21.9    56.174095    90.155128
#
#             LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  \
# Date
# 2013-06-30         28.074101         23.006936  6.818887   69.451805
# 2013-06-30         29.850689         24.035009  5.691890   51.937448
# 2013-06-30         30.091292         24.565633  6.138224   20.573050
# 2013-06-30         29.704629         23.326177  5.650050   65.727144
# 2013-06-30         29.113934         23.486480  5.735004  107.965535
#
#             LDAPS_CC1  ...  LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  \
# ...

# %%
y.head()
# Out:
# Date
# 2013-06-30    29.1
# 2013-06-30    30.5
# 2013-06-30    31.1
# 2013-06-30    31.7
# 2013-06-30    31.2
# Name: Next_Tmax, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)

# %%
lm = LinearRegression()
lm.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lm.score(x_train,y_train)
# Out:
# 0.7806932100909276

# %% [markdown]
# here our Linear regression model accuracy is 78 % for prection of max temperature of next day.

# %%
predtmax=lm.predict(x_test)
print('Predicted temp:',predtmax)
print('actual temp',y_test)
# Out:
# Predicted temp: [27.91831638 25.21427458 33.2769654  ... 30.59374548 24.84386195
#  29.25130807]
# actual temp Date
# 2016-07-23    28.7
# 2017-07-02    27.8
# 2014-07-09    33.6
# 2013-08-28    25.5
# 2013-07-23    29.4
#               ...
# 2014-07-08    32.5
# 2016-08-02    34.7
# 2014-08-29    30.0
# 2014-08-13    22.0
# 2015-07-07    25.9
# Name: Next_Tmax, Length: 1518, dtype: float64

# %% [markdown]
# here above we can see actual max temperature and predicted max temperature by our model.

# %%
print('Mean absolute error',mean_absolute_error(y_test,predtmax))
print('Mean squared error',mean_squared_error(y_test,predtmax))
print('Root mean Squared Error', np.sqrt(mean_squared_error(y_test,predtmax)))
# Out:
# Mean absolute error 1.0956366283897234
# Mean squared error 2.083788776105953
# Root mean Squared Error 1.4435334343568054

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,predtmax))

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

# %%
alphavalue={'alpha':[1,0,0.1,0.01,0.001,0.0001,0]}
model=Ridge()
grid=GridSearchCV(estimator=model, param_grid=alphavalue)
grid.fit(x_train,y_train)
print(grid.best_score_)
print(grid.best_estimator_.alpha)
print(grid.best_params_)
# Out:
# 0.7789013618257064
# 1
# {'alpha': 1}

# %%
from sklearn.linear_model import Lasso, Ridge

# %%
ls=Lasso(alpha=1)
ls.fit(x_train,y_train)
print(ls.score(x_train,y_train))
predlasso=ls.predict(x_test)
# Out:
# 0.717844498254692

# %%
import joblib
joblib.dump(predtmax, 'Max_temp_prediction.pkl')
# Out:
# ['Max_temp_prediction.pkl']

# %% [markdown]
# # Predcting TMin

# %%
x1=df1.iloc[:,0:23]
y1=df1.iloc[:,-1]

# %%
x1.head()
# Out:
#             station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# Date
# 2013-06-30      1.0          28.7          21.4    58.255688    91.116364
# 2013-06-30      2.0          31.9          21.6    52.263397    90.604721
# 2013-06-30      3.0          31.6          23.3    48.690479    83.973587
# 2013-06-30      4.0          32.0          23.4    58.239788    96.483688
# 2013-06-30      5.0          31.4          21.9    56.174095    90.155128
#
#             LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  \
# Date
# 2013-06-30         28.074101         23.006936  6.818887   69.451805
# 2013-06-30         29.850689         24.035009  5.691890   51.937448
# 2013-06-30         30.091292         24.565633  6.138224   20.573050
# 2013-06-30         29.704629         23.326177  5.650050   65.727144
# 2013-06-30         29.113934         23.486480  5.735004  107.965535
#
#             LDAPS_CC1  ...  LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4  \
# ...

# %%
y1.head()
# Out:
# Date
# 2013-06-30    21.2
# 2013-06-30    22.5
# 2013-06-30    23.9
# 2013-06-30    24.3
# 2013-06-30    22.5
# Name: Next_Tmin, dtype: float64

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=.25,random_state=42)

# %%
lm = LinearRegression()
lm.fit(x1_train, y1_train)
# Out:
# LinearRegression()

# %%
lm.score(x1_train,y1_train)
# Out:
# 0.8540106621195376

# %% [markdown]
# here our Linear regression model accuracy is 85 % for prection of min temperature of next day.

# %%
predtmin=lm.predict(x1_test)
print('Predicted temp:',predtmin)
print('actual temp',y1_test)
# Out:
# Predicted temp: [24.2681357  22.30941346 23.65425806 ... 24.77920038 20.46766759
#  24.92101883]
# actual temp Date
# 2016-07-23    24.5
# 2017-07-02    21.5
# 2014-07-09    24.7
# 2013-08-28    22.5
# 2013-07-23    23.3
#               ...
# 2014-08-04    24.6
# 2017-08-12    24.7
# 2015-07-10    24.4
# 2016-07-17    20.1
# 2013-08-09    25.8
# Name: Next_Tmin, Length: 1897, dtype: float64

# %% [markdown]
# here above we can see actual min temperature and predicted min temperature by our mpdel for next day.

# %%
joblib.dump(predtmin, 'Min_temp_prediction.pkl')
# Out:
# ['Min_temp_prediction.pkl']

# %% [markdown]
# At the end Saving model.
